# %% [markdown]
# # 4章 word2vecの高速化

# %%
import sys
sys.path.append('..')
from common.np import *  # import numpy as np
from common.layers import Embedding, SigmoidWithLoss
import collections

class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh


class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）で計算するときは、速度を優先
            # 負例にターゲットが含まれるケースがある
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample


class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 正例のフォワード
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 負例のフォワード
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %%
class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 重みの初期化
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # レイヤの生成
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embeddingレイヤを使用
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # すべての重みと勾配をリストにまとめる
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # メンバ変数に単語の分散表現を設定
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
class SkipGram:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size
        rn = np.random.randn

        # 重みの初期化
        W_in = 0.01 * rn(V, H).astype('f')
        W_out = 0.01 * rn(V, H).astype('f')

        # レイヤの生成
        self.in_layer = Embedding(W_in)
        self.loss_layers = []
        for i in range(2 * window_size):
            layer = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
            self.loss_layers.append(layer)

        # すべての重みと勾配をリストにまとめる
        layers = [self.in_layer] + self.loss_layers
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # メンバ変数に単語の分散表現を設定
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = self.in_layer.forward(target)

        loss = 0
        for i, layer in enumerate(self.loss_layers):
            loss += layer.forward(h, contexts[:, i])
        return loss

    def backward(self, dout=1):
        dh = 0
        for i, layer in enumerate(self.loss_layers):
            dh += layer.backward(dout)
        self.in_layer.backward(dh)
        return None

# %%
from common import config
# GPUで実行する場合は、下記のコメントアウトを消去（要cupy）
# ===============================================
# config.GPU = True
# ===============================================
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

# ハイパーパラメータの設定
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)

# モデルなどの生成
model = CBOW(vocab_size, hidden_size, window_size, corpus)
# model = SkipGram(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 学習開始
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 後ほど利用できるように、必要なデータを保存
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'  # or 'skipgram_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | epoch 1 |  iter 1 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 21 / 9295 | time 1[s] | loss 4.16
# | epoch 1 |  iter 41 / 9295 | time 3[s] | loss 4.15
# | epoch 1 |  iter 61 / 9295 | time 4[s] | loss 4.12
# | epoch 1 |  iter 81 / 9295 | time 6[s] | loss 4.05
# | epoch 1 |  iter 101 / 9295 | time 7[s] | loss 3.92
# | epoch 1 |  iter 121 / 9295 | time 9[s] | loss 3.77
# | epoch 1 |  iter 141 / 9295 | time 10[s] | loss 3.62
# | epoch 1 |  iter 161 / 9295 | time 12[s] | loss 3.49
# | epoch 1 |  iter 181 / 9295 | time 13[s] | loss 3.35
# | epoch 1 |  iter 201 / 9295 | time 15[s] | loss 3.25
# | epoch 1 |  iter 221 / 9295 | time 17[s] | loss 3.16
# | epoch 1 |  iter 241 / 9295 | time 18[s] | loss 3.07
# | epoch 1 |  iter 261 / 9295 | time 20[s] | loss 3.02
# | epoch 1 |  iter 281 / 9295 | time 21[s] | loss 2.97
# | epoch 1 |  iter 301 / 9295 | time 22[s] | loss 2.92
# | epoch 1 |  iter 321 / 9295 | time 24[s] | loss 2.88
# | epoch 1 |  iter 341 / 9295 | time 25[s] | loss 2.85
# | epoch 1 |  iter 361 / 9295 | time 27[s] | loss 2.80
# | epoch 1 |  iter 381 / 9295 | time 28[s] | loss 2.78
# | epoch 1 |  iter 401 / 9295 | time 30[s] | loss 2.77
# | epoch 1 |  iter 421 / 9295 | time 31[s] | loss 2.73
# | epoch 1 |  iter 441 / 9295 | time 32[s] | loss 2.73
# | epoch 1 |  iter 461 / 9295 | time 34[s] | loss 2.75
# | epoch 1 |  iter 481 / 9295 | time 35[s] | loss 2.71
# | epoch 1 |  iter 501 / 9295 | time 37[s] | loss 2.70
# | epoch 1 |  iter 521 / 9295 | time 38[s] | loss 2.67
# | epoch 1 |  iter 541 / 9295 | time 40[s] | loss 2.67
# | epoch 1 |  iter 561 / 9295 | time 41[s] | loss 2.66
# | epoch 1 |  iter 581 / 9295 | time 42[s] | loss 2.66
# | epoch 1 |  iter 601 / 9295 | time 44[s] | loss 2.66
# | epoch 1 |  iter 621 / 9295 | time 45[s] | loss 2.61
# | epoch 1 |  iter 641 / 9295 | time 47[s] | loss 2.63
# | epoch 1 |  iter 661 / 9295 | time 48[s] | loss 2.63
# | epoch 1 |  iter 681 / 9295 | time 49[s] | loss 2.60
# | epoch 1 |  iter 701 / 9295 | time 51[s] | loss 2.61
# | epoch 1 |  iter 721 / 9295 | time 52[s] | loss 2.62
# | epoch 1 |  iter 741 / 9295 | time 54[s] | loss 2.59
# | epoch 1 |  iter 761 / 9295 | time 55[s] | loss 2.57
# | epoch 1 |  iter 781 / 9295 | time 56[s] | loss 2.58
# | epoch 1 |  iter 801 / 9295 | time 58[s] | loss 2.58
# | epoch 1 |  iter 821 / 9295 | time 60[s] | loss 2.59
# | epoch 1 |  iter 841 / 9295 | time 61[s] | loss 2.56
# | epoch 1 |  iter 861 / 9295 | time 63[s] | loss 2.58
# | epoch 1 |  iter 881 / 9295 | time 64[s] | loss 2.52
# | epoch 1 |  iter 901 / 9295 | time 65[s] | loss 2.58
# | epoch 1 |  iter 921 / 9295 | time 67[s] | loss 2.57
# | epoch 1 |  iter 941 / 9295 | time 68[s] | loss 2.54
# | epoch 1 |  iter 961 / 9295 | time 70[s] | loss 2.55
# | epoch 1 |  iter 981 / 9295 | time 71[s] | loss 2.54
# | epoch 1 |  iter 1001 / 9295 | time 73[s] | loss 2.57
# | epoch 1 |  iter 1021 / 9295 | time 75[s] | loss 2.54
# | epoch 1 |  iter 1041 / 9295 | time 76[s] | loss 2.53
# | epoch 1 |  iter 1061 / 9295 | time 78[s] | loss 2.58
# | epoch 1 |  iter 1081 / 9295 | time 79[s] | loss 2.54
# | epoch 1 |  iter 1101 / 9295 | time 81[s] | loss 2.56
# | epoch 1 |  iter 1121 / 9295 | time 82[s] | loss 2.58
# | epoch 1 |  iter 1141 / 9295 | time 84[s] | loss 2.56
# | epoch 1 |  iter 1161 / 9295 | time 85[s] | loss 2.53
# | epoch 1 |  iter 1181 / 9295 | time 87[s] | loss 2.55
# | epoch 1 |  iter 1201 / 9295 | time 88[s] | loss 2.54
# | epoch 1 |  iter 1221 / 9295 | time 90[s] | loss 2.55
# | epoch 1 |  iter 1241 / 9295 | time 91[s] | loss 2.53
# | epoch 1 |  iter 1261 / 9295 | time 92[s] | loss 2.53
# | epoch 1 |  iter 1281 / 9295 | time 94[s] | loss 2.50
# | epoch 1 |  iter 1301 / 9295 | time 96[s] | loss 2.52
# | epoch 1 |  iter 1321 / 9295 | time 97[s] | loss 2.50
# | epoch 1 |  iter 1341 / 9295 | time 99[s] | loss 2.51
# | epoch 1 |  iter 1361 / 9295 | time 100[s] | loss 2.52
# | epoch 1 |  iter 1381 / 9295 | time 102[s] | loss 2.54
# | epoch 1 |  iter 1401 / 9295 | time 103[s] | loss 2.54
# | epoch 1 |  iter 1421 / 9295 | time 105[s] | loss 2.54
# | epoch 1 |  iter 1441 / 9295 | time 106[s] | loss 2.53
# | epoch 1 |  iter 1461 / 9295 | time 108[s] | loss 2.50
# | epoch 1 |  iter 1481 / 9295 | time 109[s] | loss 2.50
# | epoch 1 |  iter 1501 / 9295 | time 111[s] | loss 2.53
# | epoch 1 |  iter 1521 / 9295 | time 113[s] | loss 2.50
# | epoch 1 |  iter 1541 / 9295 | time 114[s] | loss 2.51
# | epoch 1 |  iter 1561 / 9295 | time 116[s] | loss 2.50
# | epoch 1 |  iter 1581 / 9295 | time 117[s] | loss 2.51
# | epoch 1 |  iter 1601 / 9295 | time 119[s] | loss 2.51
# | epoch 1 |  iter 1621 / 9295 | time 121[s] | loss 2.50
# | epoch 1 |  iter 1641 / 9295 | time 122[s] | loss 2.49
# | epoch 1 |  iter 1661 / 9295 | time 124[s] | loss 2.49
# | epoch 1 |  iter 1681 / 9295 | time 125[s] | loss 2.49
# | epoch 1 |  iter 1701 / 9295 | time 127[s] | loss 2.50
# | epoch 1 |  iter 1721 / 9295 | time 128[s] | loss 2.51
# | epoch 1 |  iter 1741 / 9295 | time 130[s] | loss 2.50
# | epoch 1 |  iter 1761 / 9295 | time 132[s] | loss 2.50
# | epoch 1 |  iter 1781 / 9295 | time 134[s] | loss 2.47
# | epoch 1 |  iter 1801 / 9295 | time 135[s] | loss 2.50
# | epoch 1 |  iter 1821 / 9295 | time 137[s] | loss 2.51
# | epoch 1 |  iter 1841 / 9295 | time 138[s] | loss 2.47
# | epoch 1 |  iter 1861 / 9295 | time 140[s] | loss 2.52
# | epoch 1 |  iter 1881 / 9295 | time 141[s] | loss 2.50
# | epoch 1 |  iter 1901 / 9295 | time 142[s] | loss 2.51
# | epoch 1 |  iter 1921 / 9295 | time 144[s] | loss 2.49
# | epoch 1 |  iter 1941 / 9295 | time 145[s] | loss 2.48
# | epoch 1 |  iter 1961 / 9295 | time 147[s] | loss 2.48
# | epoch 1 |  iter 1981 / 9295 | time 148[s] | loss 2.49
# | epoch 1 |  iter 2001 / 9295 | time 150[s] | loss 2.49
# | epoch 1 |  iter 2021 / 9295 | time 151[s] | loss 2.47
# | epoch 1 |  iter 2041 / 9295 | time 153[s] | loss 2.50
# | epoch 1 |  iter 2061 / 9295 | time 154[s] | loss 2.51
# | epoch 1 |  iter 2081 / 9295 | time 156[s] | loss 2.50
# | epoch 1 |  iter 2101 / 9295 | time 157[s] | loss 2.49
# | epoch 1 |  iter 2121 / 9295 | time 159[s] | loss 2.51
# | epoch 1 |  iter 2141 / 9295 | time 160[s] | loss 2.47
# | epoch 1 |  iter 2161 / 9295 | time 162[s] | loss 2.49
# | epoch 1 |  iter 2181 / 9295 | time 164[s] | loss 2.46
# | epoch 1 |  iter 2201 / 9295 | time 165[s] | loss 2.46
# | epoch 1 |  iter 2221 / 9295 | time 167[s] | loss 2.50
# | epoch 1 |  iter 2241 / 9295 | time 168[s] | loss 2.46
# | epoch 1 |  iter 2261 / 9295 | time 170[s] | loss 2.49
# | epoch 1 |  iter 2281 / 9295 | time 171[s] | loss 2.48
# | epoch 1 |  iter 2301 / 9295 | time 173[s] | loss 2.49
# | epoch 1 |  iter 2321 / 9295 | time 175[s] | loss 2.50
# | epoch 1 |  iter 2341 / 9295 | time 176[s] | loss 2.50
# | epoch 1 |  iter 2361 / 9295 | time 178[s] | loss 2.46
# | epoch 1 |  iter 2381 / 9295 | time 179[s] | loss 2.50
# | epoch 1 |  iter 2401 / 9295 | time 181[s] | loss 2.47
# | epoch 1 |  iter 2421 / 9295 | time 183[s] | loss 2.48
# | epoch 1 |  iter 2441 / 9295 | time 184[s] | loss 2.46
# | epoch 1 |  iter 2461 / 9295 | time 186[s] | loss 2.49
# | epoch 1 |  iter 2481 / 9295 | time 187[s] | loss 2.49
# | epoch 1 |  iter 2501 / 9295 | time 189[s] | loss 2.50
# | epoch 1 |  iter 2521 / 9295 | time 190[s] | loss 2.47
# | epoch 1 |  iter 2541 / 9295 | time 192[s] | loss 2.46
# | epoch 1 |  iter 2561 / 9295 | time 193[s] | loss 2.48
# | epoch 1 |  iter 2581 / 9295 | time 195[s] | loss 2.48
# | epoch 1 |  iter 2601 / 9295 | time 197[s] | loss 2.44
# | epoch 1 |  iter 2621 / 9295 | time 198[s] | loss 2.47
# | epoch 1 |  iter 2641 / 9295 | time 200[s] | loss 2.47
# | epoch 1 |  iter 2661 / 9295 | time 201[s] | loss 2.45
# | epoch 1 |  iter 2681 / 9295 | time 203[s] | loss 2.44
# | epoch 1 |  iter 2701 / 9295 | time 205[s] | loss 2.48
# | epoch 1 |  iter 2721 / 9295 | time 207[s] | loss 2.40
# | epoch 1 |  iter 2741 / 9295 | time 208[s] | loss 2.46
# | epoch 1 |  iter 2761 / 9295 | time 210[s] | loss 2.49
# | epoch 1 |  iter 2781 / 9295 | time 211[s] | loss 2.48
# | epoch 1 |  iter 2801 / 9295 | time 213[s] | loss 2.46
# | epoch 1 |  iter 2821 / 9295 | time 214[s] | loss 2.46
# | epoch 1 |  iter 2841 / 9295 | time 216[s] | loss 2.45
# | epoch 1 |  iter 2861 / 9295 | time 217[s] | loss 2.44
# | epoch 1 |  iter 2881 / 9295 | time 219[s] | loss 2.43
# | epoch 1 |  iter 2901 / 9295 | time 221[s] | loss 2.43
# | epoch 1 |  iter 2921 / 9295 | time 222[s] | loss 2.48
# | epoch 1 |  iter 2941 / 9295 | time 224[s] | loss 2.46
# | epoch 1 |  iter 2961 / 9295 | time 225[s] | loss 2.44
# | epoch 1 |  iter 2981 / 9295 | time 227[s] | loss 2.46
# | epoch 1 |  iter 3001 / 9295 | time 228[s] | loss 2.43
# | epoch 1 |  iter 3021 / 9295 | time 230[s] | loss 2.43
# | epoch 1 |  iter 3041 / 9295 | time 231[s] | loss 2.44
# | epoch 1 |  iter 3061 / 9295 | time 233[s] | loss 2.46
# | epoch 1 |  iter 3081 / 9295 | time 234[s] | loss 2.44
# | epoch 1 |  iter 3101 / 9295 | time 236[s] | loss 2.47
# | epoch 1 |  iter 3121 / 9295 | time 237[s] | loss 2.45
# | epoch 1 |  iter 3141 / 9295 | time 239[s] | loss 2.48
# | epoch 1 |  iter 3161 / 9295 | time 240[s] | loss 2.44
# | epoch 1 |  iter 3181 / 9295 | time 242[s] | loss 2.42
# | epoch 1 |  iter 3201 / 9295 | time 243[s] | loss 2.46
# | epoch 1 |  iter 3221 / 9295 | time 245[s] | loss 2.46
# | epoch 1 |  iter 3241 / 9295 | time 246[s] | loss 2.44
# | epoch 1 |  iter 3261 / 9295 | time 248[s] | loss 2.41
# | epoch 1 |  iter 3281 / 9295 | time 249[s] | loss 2.44
# | epoch 1 |  iter 3301 / 9295 | time 251[s] | loss 2.44
# | epoch 1 |  iter 3321 / 9295 | time 252[s] | loss 2.42
# | epoch 1 |  iter 3341 / 9295 | time 254[s] | loss 2.44
# | epoch 1 |  iter 3361 / 9295 | time 255[s] | loss 2.43
# | epoch 1 |  iter 3381 / 9295 | time 257[s] | loss 2.42
# | epoch 1 |  iter 3401 / 9295 | time 258[s] | loss 2.43
# | epoch 1 |  iter 3421 / 9295 | time 260[s] | loss 2.39
# | epoch 1 |  iter 3441 / 9295 | time 261[s] | loss 2.40
# | epoch 1 |  iter 3461 / 9295 | time 263[s] | loss 2.41
# | epoch 1 |  iter 3481 / 9295 | time 264[s] | loss 2.46
# | epoch 1 |  iter 3501 / 9295 | time 266[s] | loss 2.44
# | epoch 1 |  iter 3521 / 9295 | time 267[s] | loss 2.40
# | epoch 1 |  iter 3541 / 9295 | time 269[s] | loss 2.42
# | epoch 1 |  iter 3561 / 9295 | time 270[s] | loss 2.42
# | epoch 1 |  iter 3581 / 9295 | time 271[s] | loss 2.44
# | epoch 1 |  iter 3601 / 9295 | time 273[s] | loss 2.43
# | epoch 1 |  iter 3621 / 9295 | time 275[s] | loss 2.43
# | epoch 1 |  iter 3641 / 9295 | time 276[s] | loss 2.41
# | epoch 1 |  iter 3661 / 9295 | time 278[s] | loss 2.41
# | epoch 1 |  iter 3681 / 9295 | time 279[s] | loss 2.45
# | epoch 1 |  iter 3701 / 9295 | time 281[s] | loss 2.43
# | epoch 1 |  iter 3721 / 9295 | time 283[s] | loss 2.42
# | epoch 1 |  iter 3741 / 9295 | time 284[s] | loss 2.40
# | epoch 1 |  iter 3761 / 9295 | time 286[s] | loss 2.41
# | epoch 1 |  iter 3781 / 9295 | time 287[s] | loss 2.40
# | epoch 1 |  iter 3801 / 9295 | time 289[s] | loss 2.41
# | epoch 1 |  iter 3821 / 9295 | time 290[s] | loss 2.37
# | epoch 1 |  iter 3841 / 9295 | time 292[s] | loss 2.39
# | epoch 1 |  iter 3861 / 9295 | time 294[s] | loss 2.41
# | epoch 1 |  iter 3881 / 9295 | time 295[s] | loss 2.42
# | epoch 1 |  iter 3901 / 9295 | time 297[s] | loss 2.43
# | epoch 1 |  iter 3921 / 9295 | time 298[s] | loss 2.40
# | epoch 1 |  iter 3941 / 9295 | time 300[s] | loss 2.41
# | epoch 1 |  iter 3961 / 9295 | time 301[s] | loss 2.41
# | epoch 1 |  iter 3981 / 9295 | time 303[s] | loss 2.42
# | epoch 1 |  iter 4001 / 9295 | time 305[s] | loss 2.42
# | epoch 1 |  iter 4021 / 9295 | time 306[s] | loss 2.41
# | epoch 1 |  iter 4041 / 9295 | time 308[s] | loss 2.43
# | epoch 1 |  iter 4061 / 9295 | time 309[s] | loss 2.40
# | epoch 1 |  iter 4081 / 9295 | time 311[s] | loss 2.44
# | epoch 1 |  iter 4101 / 9295 | time 312[s] | loss 2.42
# | epoch 1 |  iter 4121 / 9295 | time 314[s] | loss 2.38
# | epoch 1 |  iter 4141 / 9295 | time 316[s] | loss 2.39
# | epoch 1 |  iter 4161 / 9295 | time 317[s] | loss 2.40
# | epoch 1 |  iter 4181 / 9295 | time 319[s] | loss 2.37
# | epoch 1 |  iter 4201 / 9295 | time 320[s] | loss 2.38
# | epoch 1 |  iter 4221 / 9295 | time 322[s] | loss 2.42
# | epoch 1 |  iter 4241 / 9295 | time 323[s] | loss 2.39
# | epoch 1 |  iter 4261 / 9295 | time 325[s] | loss 2.37
# | epoch 1 |  iter 4281 / 9295 | time 326[s] | loss 2.39
# | epoch 1 |  iter 4301 / 9295 | time 328[s] | loss 2.39
# | epoch 1 |  iter 4321 / 9295 | time 329[s] | loss 2.38
# | epoch 1 |  iter 4341 / 9295 | time 331[s] | loss 2.38
# | epoch 1 |  iter 4361 / 9295 | time 332[s] | loss 2.42
# | epoch 1 |  iter 4381 / 9295 | time 334[s] | loss 2.41
# | epoch 1 |  iter 4401 / 9295 | time 335[s] | loss 2.41
# | epoch 1 |  iter 4421 / 9295 | time 337[s] | loss 2.41
# | epoch 1 |  iter 4441 / 9295 | time 338[s] | loss 2.41
# | epoch 1 |  iter 4461 / 9295 | time 340[s] | loss 2.37
# | epoch 1 |  iter 4481 / 9295 | time 341[s] | loss 2.40
# | epoch 1 |  iter 4501 / 9295 | time 343[s] | loss 2.38
# | epoch 1 |  iter 4521 / 9295 | time 344[s] | loss 2.38
# | epoch 1 |  iter 4541 / 9295 | time 346[s] | loss 2.36
# | epoch 1 |  iter 4561 / 9295 | time 347[s] | loss 2.41
# | epoch 1 |  iter 4581 / 9295 | time 349[s] | loss 2.41
# | epoch 1 |  iter 4601 / 9295 | time 350[s] | loss 2.38
# | epoch 1 |  iter 4621 / 9295 | time 352[s] | loss 2.38
# | epoch 1 |  iter 4641 / 9295 | time 354[s] | loss 2.37
# | epoch 1 |  iter 4661 / 9295 | time 355[s] | loss 2.37
# | epoch 1 |  iter 4681 / 9295 | time 357[s] | loss 2.38
# | epoch 1 |  iter 4701 / 9295 | time 358[s] | loss 2.38
# | epoch 1 |  iter 4721 / 9295 | time 360[s] | loss 2.41
# | epoch 1 |  iter 4741 / 9295 | time 362[s] | loss 2.38
# | epoch 1 |  iter 4761 / 9295 | time 363[s] | loss 2.39
# | epoch 1 |  iter 4781 / 9295 | time 365[s] | loss 2.37
# | epoch 1 |  iter 4801 / 9295 | time 367[s] | loss 2.38
# | epoch 1 |  iter 4821 / 9295 | time 368[s] | loss 2.40
# | epoch 1 |  iter 4841 / 9295 | time 370[s] | loss 2.37
# | epoch 1 |  iter 4861 / 9295 | time 371[s] | loss 2.36
# | epoch 1 |  iter 4881 / 9295 | time 373[s] | loss 2.33
# | epoch 1 |  iter 4901 / 9295 | time 374[s] | loss 2.38
# | epoch 1 |  iter 4921 / 9295 | time 376[s] | loss 2.33
# | epoch 1 |  iter 4941 / 9295 | time 377[s] | loss 2.34
# | epoch 1 |  iter 4961 / 9295 | time 380[s] | loss 2.36
# | epoch 1 |  iter 4981 / 9295 | time 381[s] | loss 2.36
# | epoch 1 |  iter 5001 / 9295 | time 383[s] | loss 2.37
# | epoch 1 |  iter 5021 / 9295 | time 385[s] | loss 2.36
# | epoch 1 |  iter 5041 / 9295 | time 387[s] | loss 2.35
# | epoch 1 |  iter 5061 / 9295 | time 388[s] | loss 2.30
# | epoch 1 |  iter 5081 / 9295 | time 390[s] | loss 2.38
# | epoch 1 |  iter 5101 / 9295 | time 392[s] | loss 2.37
# | epoch 1 |  iter 5121 / 9295 | time 393[s] | loss 2.36
# | epoch 1 |  iter 5141 / 9295 | time 395[s] | loss 2.36
# | epoch 1 |  iter 5161 / 9295 | time 397[s] | loss 2.35
# | epoch 1 |  iter 5181 / 9295 | time 398[s] | loss 2.34
# | epoch 1 |  iter 5201 / 9295 | time 400[s] | loss 2.34
# | epoch 1 |  iter 5221 / 9295 | time 401[s] | loss 2.37
# | epoch 1 |  iter 5241 / 9295 | time 403[s] | loss 2.35
# | epoch 1 |  iter 5261 / 9295 | time 404[s] | loss 2.34
# | epoch 1 |  iter 5281 / 9295 | time 406[s] | loss 2.35
# | epoch 1 |  iter 5301 / 9295 | time 408[s] | loss 2.35
# | epoch 1 |  iter 5321 / 9295 | time 409[s] | loss 2.35
# | epoch 1 |  iter 5341 / 9295 | time 411[s] | loss 2.36
# | epoch 1 |  iter 5361 / 9295 | time 412[s] | loss 2.31
# | epoch 1 |  iter 5381 / 9295 | time 414[s] | loss 2.35
# | epoch 1 |  iter 5401 / 9295 | time 416[s] | loss 2.36
# | epoch 1 |  iter 5421 / 9295 | time 417[s] | loss 2.36
# | epoch 1 |  iter 5441 / 9295 | time 419[s] | loss 2.30
# | epoch 1 |  iter 5461 / 9295 | time 420[s] | loss 2.30
# | epoch 1 |  iter 5481 / 9295 | time 422[s] | loss 2.33
# | epoch 1 |  iter 5501 / 9295 | time 423[s] | loss 2.34
# | epoch 1 |  iter 5521 / 9295 | time 425[s] | loss 2.34
# | epoch 1 |  iter 5541 / 9295 | time 426[s] | loss 2.32
# | epoch 1 |  iter 5561 / 9295 | time 428[s] | loss 2.30
# | epoch 1 |  iter 5581 / 9295 | time 429[s] | loss 2.33
# | epoch 1 |  iter 5601 / 9295 | time 431[s] | loss 2.32
# | epoch 1 |  iter 5621 / 9295 | time 433[s] | loss 2.34
# | epoch 1 |  iter 5641 / 9295 | time 434[s] | loss 2.32
# | epoch 1 |  iter 5661 / 9295 | time 436[s] | loss 2.37
# | epoch 1 |  iter 5681 / 9295 | time 437[s] | loss 2.33
# | epoch 1 |  iter 5701 / 9295 | time 439[s] | loss 2.34
# | epoch 1 |  iter 5721 / 9295 | time 440[s] | loss 2.37
# | epoch 1 |  iter 5741 / 9295 | time 442[s] | loss 2.33
# | epoch 1 |  iter 5761 / 9295 | time 444[s] | loss 2.30
# | epoch 1 |  iter 5781 / 9295 | time 445[s] | loss 2.31
# | epoch 1 |  iter 5801 / 9295 | time 447[s] | loss 2.36
# | epoch 1 |  iter 5821 / 9295 | time 448[s] | loss 2.30
# | epoch 1 |  iter 5841 / 9295 | time 450[s] | loss 2.32
# | epoch 1 |  iter 5861 / 9295 | time 451[s] | loss 2.32
# | epoch 1 |  iter 5881 / 9295 | time 453[s] | loss 2.34
# | epoch 1 |  iter 5901 / 9295 | time 455[s] | loss 2.30
# | epoch 1 |  iter 5921 / 9295 | time 456[s] | loss 2.31
# | epoch 1 |  iter 5941 / 9295 | time 458[s] | loss 2.33
# | epoch 1 |  iter 5961 / 9295 | time 459[s] | loss 2.37
# | epoch 1 |  iter 5981 / 9295 | time 461[s] | loss 2.29
# | epoch 1 |  iter 6001 / 9295 | time 462[s] | loss 2.32
# | epoch 1 |  iter 6021 / 9295 | time 464[s] | loss 2.31
# | epoch 1 |  iter 6041 / 9295 | time 466[s] | loss 2.32
# | epoch 1 |  iter 6061 / 9295 | time 467[s] | loss 2.31
# | epoch 1 |  iter 6081 / 9295 | time 469[s] | loss 2.33
# | epoch 1 |  iter 6101 / 9295 | time 470[s] | loss 2.33
# | epoch 1 |  iter 6121 / 9295 | time 472[s] | loss 2.30
# | epoch 1 |  iter 6141 / 9295 | time 474[s] | loss 2.32
# | epoch 1 |  iter 6161 / 9295 | time 475[s] | loss 2.32
# | epoch 1 |  iter 6181 / 9295 | time 477[s] | loss 2.31
# | epoch 1 |  iter 6201 / 9295 | time 478[s] | loss 2.30
# | epoch 1 |  iter 6221 / 9295 | time 480[s] | loss 2.30
# | epoch 1 |  iter 6241 / 9295 | time 481[s] | loss 2.31
# | epoch 1 |  iter 6261 / 9295 | time 483[s] | loss 2.28
# | epoch 1 |  iter 6281 / 9295 | time 485[s] | loss 2.31
# | epoch 1 |  iter 6301 / 9295 | time 486[s] | loss 2.34
# | epoch 1 |  iter 6321 / 9295 | time 488[s] | loss 2.30
# | epoch 1 |  iter 6341 / 9295 | time 489[s] | loss 2.32
# | epoch 1 |  iter 6361 / 9295 | time 491[s] | loss 2.26
# | epoch 1 |  iter 6381 / 9295 | time 492[s] | loss 2.33
# | epoch 1 |  iter 6401 / 9295 | time 494[s] | loss 2.31
# | epoch 1 |  iter 6421 / 9295 | time 495[s] | loss 2.35
# | epoch 1 |  iter 6441 / 9295 | time 497[s] | loss 2.30
# | epoch 1 |  iter 6461 / 9295 | time 498[s] | loss 2.33
# | epoch 1 |  iter 6481 / 9295 | time 500[s] | loss 2.30
# | epoch 1 |  iter 6501 / 9295 | time 501[s] | loss 2.31
# | epoch 1 |  iter 6521 / 9295 | time 503[s] | loss 2.29
# | epoch 1 |  iter 6541 / 9295 | time 504[s] | loss 2.30
# | epoch 1 |  iter 6561 / 9295 | time 506[s] | loss 2.30
# | epoch 1 |  iter 6581 / 9295 | time 507[s] | loss 2.28
# | epoch 1 |  iter 6601 / 9295 | time 508[s] | loss 2.33
# | epoch 1 |  iter 6621 / 9295 | time 510[s] | loss 2.27
# | epoch 1 |  iter 6641 / 9295 | time 511[s] | loss 2.30
# | epoch 1 |  iter 6661 / 9295 | time 513[s] | loss 2.32
# | epoch 1 |  iter 6681 / 9295 | time 514[s] | loss 2.28
# | epoch 1 |  iter 6701 / 9295 | time 516[s] | loss 2.30
# | epoch 1 |  iter 6721 / 9295 | time 517[s] | loss 2.31
# | epoch 1 |  iter 6741 / 9295 | time 519[s] | loss 2.27
# | epoch 1 |  iter 6761 / 9295 | time 520[s] | loss 2.32
# | epoch 1 |  iter 6781 / 9295 | time 522[s] | loss 2.30
# | epoch 1 |  iter 6801 / 9295 | time 523[s] | loss 2.31
# | epoch 1 |  iter 6821 / 9295 | time 525[s] | loss 2.27
# | epoch 1 |  iter 6841 / 9295 | time 527[s] | loss 2.31
# | epoch 1 |  iter 6861 / 9295 | time 528[s] | loss 2.29
# | epoch 1 |  iter 6881 / 9295 | time 530[s] | loss 2.29
# | epoch 1 |  iter 6901 / 9295 | time 531[s] | loss 2.26
# | epoch 1 |  iter 6921 / 9295 | time 533[s] | loss 2.29
# | epoch 1 |  iter 6941 / 9295 | time 535[s] | loss 2.31
# | epoch 1 |  iter 6961 / 9295 | time 536[s] | loss 2.28
# | epoch 1 |  iter 6981 / 9295 | time 538[s] | loss 2.28
# | epoch 1 |  iter 7001 / 9295 | time 539[s] | loss 2.28
# | epoch 1 |  iter 7021 / 9295 | time 541[s] | loss 2.27
# | epoch 1 |  iter 7041 / 9295 | time 543[s] | loss 2.27
# | epoch 1 |  iter 7061 / 9295 | time 544[s] | loss 2.29
# | epoch 1 |  iter 7081 / 9295 | time 546[s] | loss 2.29
# | epoch 1 |  iter 7101 / 9295 | time 547[s] | loss 2.24
# | epoch 1 |  iter 7121 / 9295 | time 549[s] | loss 2.28
# | epoch 1 |  iter 7141 / 9295 | time 550[s] | loss 2.30
# | epoch 1 |  iter 7161 / 9295 | time 552[s] | loss 2.29
# | epoch 1 |  iter 7181 / 9295 | time 553[s] | loss 2.27
# | epoch 1 |  iter 7201 / 9295 | time 555[s] | loss 2.28
# | epoch 1 |  iter 7221 / 9295 | time 556[s] | loss 2.26
# | epoch 1 |  iter 7241 / 9295 | time 558[s] | loss 2.26
# | epoch 1 |  iter 7261 / 9295 | time 559[s] | loss 2.27
# | epoch 1 |  iter 7281 / 9295 | time 561[s] | loss 2.26
# | epoch 1 |  iter 7301 / 9295 | time 562[s] | loss 2.26
# | epoch 1 |  iter 7321 / 9295 | time 564[s] | loss 2.29
# | epoch 1 |  iter 7341 / 9295 | time 565[s] | loss 2.27
# | epoch 1 |  iter 7361 / 9295 | time 567[s] | loss 2.29
# | epoch 1 |  iter 7381 / 9295 | time 568[s] | loss 2.25
# | epoch 1 |  iter 7401 / 9295 | time 570[s] | loss 2.30
# | epoch 1 |  iter 7421 / 9295 | time 571[s] | loss 2.26
# | epoch 1 |  iter 7441 / 9295 | time 573[s] | loss 2.27
# | epoch 1 |  iter 7461 / 9295 | time 574[s] | loss 2.27
# | epoch 1 |  iter 7481 / 9295 | time 576[s] | loss 2.27
# | epoch 1 |  iter 7501 / 9295 | time 577[s] | loss 2.24
# | epoch 1 |  iter 7521 / 9295 | time 579[s] | loss 2.29
# | epoch 1 |  iter 7541 / 9295 | time 580[s] | loss 2.26
# | epoch 1 |  iter 7561 / 9295 | time 583[s] | loss 2.27
# | epoch 1 |  iter 7581 / 9295 | time 584[s] | loss 2.29
# | epoch 1 |  iter 7601 / 9295 | time 586[s] | loss 2.27
# | epoch 1 |  iter 7621 / 9295 | time 588[s] | loss 2.24
# | epoch 1 |  iter 7641 / 9295 | time 589[s] | loss 2.26
# | epoch 1 |  iter 7661 / 9295 | time 591[s] | loss 2.25
# | epoch 1 |  iter 7681 / 9295 | time 592[s] | loss 2.24
# | epoch 1 |  iter 7701 / 9295 | time 594[s] | loss 2.27
# | epoch 1 |  iter 7721 / 9295 | time 595[s] | loss 2.25
# | epoch 1 |  iter 7741 / 9295 | time 597[s] | loss 2.28
# | epoch 1 |  iter 7761 / 9295 | time 598[s] | loss 2.23
# | epoch 1 |  iter 7781 / 9295 | time 600[s] | loss 2.27
# | epoch 1 |  iter 7801 / 9295 | time 601[s] | loss 2.28
# | epoch 1 |  iter 7821 / 9295 | time 602[s] | loss 2.25
# | epoch 1 |  iter 7841 / 9295 | time 604[s] | loss 2.26
# | epoch 1 |  iter 7861 / 9295 | time 605[s] | loss 2.27
# | epoch 1 |  iter 7881 / 9295 | time 607[s] | loss 2.23
# | epoch 1 |  iter 7901 / 9295 | time 608[s] | loss 2.26
# | epoch 1 |  iter 7921 / 9295 | time 610[s] | loss 2.24
# | epoch 1 |  iter 7941 / 9295 | time 611[s] | loss 2.26
# | epoch 1 |  iter 7961 / 9295 | time 612[s] | loss 2.25
# | epoch 1 |  iter 7981 / 9295 | time 614[s] | loss 2.24
# | epoch 1 |  iter 8001 / 9295 | time 615[s] | loss 2.26
# | epoch 1 |  iter 8021 / 9295 | time 617[s] | loss 2.28
# | epoch 1 |  iter 8041 / 9295 | time 618[s] | loss 2.27
# | epoch 1 |  iter 8061 / 9295 | time 620[s] | loss 2.27
# | epoch 1 |  iter 8081 / 9295 | time 621[s] | loss 2.24
# | epoch 1 |  iter 8101 / 9295 | time 623[s] | loss 2.29
# | epoch 1 |  iter 8121 / 9295 | time 624[s] | loss 2.28
# | epoch 1 |  iter 8141 / 9295 | time 625[s] | loss 2.28
# | epoch 1 |  iter 8161 / 9295 | time 627[s] | loss 2.28
# | epoch 1 |  iter 8181 / 9295 | time 628[s] | loss 2.27
# | epoch 1 |  iter 8201 / 9295 | time 630[s] | loss 2.28
# | epoch 1 |  iter 8221 / 9295 | time 631[s] | loss 2.26
# | epoch 1 |  iter 8241 / 9295 | time 633[s] | loss 2.24
# | epoch 1 |  iter 8261 / 9295 | time 634[s] | loss 2.24
# | epoch 1 |  iter 8281 / 9295 | time 635[s] | loss 2.22
# | epoch 1 |  iter 8301 / 9295 | time 637[s] | loss 2.24
# | epoch 1 |  iter 8321 / 9295 | time 638[s] | loss 2.26
# | epoch 1 |  iter 8341 / 9295 | time 640[s] | loss 2.21
# | epoch 1 |  iter 8361 / 9295 | time 641[s] | loss 2.25
# | epoch 1 |  iter 8381 / 9295 | time 643[s] | loss 2.25
# | epoch 1 |  iter 8401 / 9295 | time 645[s] | loss 2.24
# | epoch 1 |  iter 8421 / 9295 | time 646[s] | loss 2.25
# | epoch 1 |  iter 8441 / 9295 | time 648[s] | loss 2.24
# | epoch 1 |  iter 8461 / 9295 | time 650[s] | loss 2.25
# | epoch 1 |  iter 8481 / 9295 | time 651[s] | loss 2.23
# | epoch 1 |  iter 8501 / 9295 | time 653[s] | loss 2.21
# | epoch 1 |  iter 8521 / 9295 | time 654[s] | loss 2.23
# | epoch 1 |  iter 8541 / 9295 | time 656[s] | loss 2.23
# | epoch 1 |  iter 8561 / 9295 | time 657[s] | loss 2.25
# | epoch 1 |  iter 8581 / 9295 | time 659[s] | loss 2.24
# | epoch 1 |  iter 8601 / 9295 | time 661[s] | loss 2.22
# | epoch 1 |  iter 8621 / 9295 | time 662[s] | loss 2.25
# | epoch 1 |  iter 8641 / 9295 | time 664[s] | loss 2.25
# | epoch 1 |  iter 8661 / 9295 | time 665[s] | loss 2.23
# | epoch 1 |  iter 8681 / 9295 | time 667[s] | loss 2.26
# | epoch 1 |  iter 8701 / 9295 | time 668[s] | loss 2.20
# | epoch 1 |  iter 8721 / 9295 | time 670[s] | loss 2.23
# | epoch 1 |  iter 8741 / 9295 | time 672[s] | loss 2.24
# | epoch 1 |  iter 8761 / 9295 | time 673[s] | loss 2.22
# | epoch 1 |  iter 8781 / 9295 | time 675[s] | loss 2.23
# | epoch 1 |  iter 8801 / 9295 | time 677[s] | loss 2.21
# | epoch 1 |  iter 8821 / 9295 | time 678[s] | loss 2.19
# | epoch 1 |  iter 8841 / 9295 | time 680[s] | loss 2.23
# | epoch 1 |  iter 8861 / 9295 | time 681[s] | loss 2.24
# | epoch 1 |  iter 8881 / 9295 | time 683[s] | loss 2.20
# | epoch 1 |  iter 8901 / 9295 | time 685[s] | loss 2.22
# | epoch 1 |  iter 8921 / 9295 | time 686[s] | loss 2.24
# | epoch 1 |  iter 8941 / 9295 | time 688[s] | loss 2.22
# | epoch 1 |  iter 8961 / 9295 | time 690[s] | loss 2.23
# | epoch 1 |  iter 8981 / 9295 | time 691[s] | loss 2.22
# | epoch 1 |  iter 9001 / 9295 | time 693[s] | loss 2.23
# | epoch 1 |  iter 9021 / 9295 | time 694[s] | loss 2.18
# | epoch 1 |  iter 9041 / 9295 | time 696[s] | loss 2.24
# | epoch 1 |  iter 9061 / 9295 | time 697[s] | loss 2.22
# | epoch 1 |  iter 9081 / 9295 | time 699[s] | loss 2.24
# | epoch 1 |  iter 9101 / 9295 | time 700[s] | loss 2.21
# | epoch 1 |  iter 9121 / 9295 | time 702[s] | loss 2.22
# | epoch 1 |  iter 9141 / 9295 | time 704[s] | loss 2.18
# | epoch 1 |  iter 9161 / 9295 | time 705[s] | loss 2.22
# | epoch 1 |  iter 9181 / 9295 | time 707[s] | loss 2.23
# | epoch 1 |  iter 9201 / 9295 | time 708[s] | loss 2.24
# | epoch 1 |  iter 9221 / 9295 | time 710[s] | loss 2.24
# | epoch 1 |  iter 9241 / 9295 | time 711[s] | loss 2.19
# | epoch 1 |  iter 9261 / 9295 | time 713[s] | loss 2.21
# | epoch 1 |  iter 9281 / 9295 | time 714[s] | loss 2.21
# | epoch 2 |  iter 1 / 9295 | time 715[s] | loss 2.21
# | epoch 2 |  iter 21 / 9295 | time 717[s] | loss 2.19
# | epoch 2 |  iter 41 / 9295 | time 719[s] | loss 2.15
# | epoch 2 |  iter 61 / 9295 | time 720[s] | loss 2.20
# | epoch 2 |  iter 81 / 9295 | time 721[s] | loss 2.15
# | epoch 2 |  iter 101 / 9295 | time 723[s] | loss 2.18
# | epoch 2 |  iter 121 / 9295 | time 724[s] | loss 2.16
# | epoch 2 |  iter 141 / 9295 | time 726[s] | loss 2.18
# | epoch 2 |  iter 161 / 9295 | time 727[s] | loss 2.17
# | epoch 2 |  iter 181 / 9295 | time 729[s] | loss 2.18
# | epoch 2 |  iter 201 / 9295 | time 730[s] | loss 2.13
# | epoch 2 |  iter 221 / 9295 | time 732[s] | loss 2.16
# | epoch 2 |  iter 241 / 9295 | time 733[s] | loss 2.17
# | epoch 2 |  iter 261 / 9295 | time 735[s] | loss 2.19
# | epoch 2 |  iter 281 / 9295 | time 736[s] | loss 2.19
# | epoch 2 |  iter 301 / 9295 | time 738[s] | loss 2.18
# | epoch 2 |  iter 321 / 9295 | time 740[s] | loss 2.16
# | epoch 2 |  iter 341 / 9295 | time 741[s] | loss 2.19
# | epoch 2 |  iter 361 / 9295 | time 743[s] | loss 2.17
# | epoch 2 |  iter 381 / 9295 | time 744[s] | loss 2.19
# | epoch 2 |  iter 401 / 9295 | time 746[s] | loss 2.20
# | epoch 2 |  iter 421 / 9295 | time 748[s] | loss 2.17
# | epoch 2 |  iter 441 / 9295 | time 749[s] | loss 2.16
# | epoch 2 |  iter 461 / 9295 | time 751[s] | loss 2.19
# | epoch 2 |  iter 481 / 9295 | time 753[s] | loss 2.19
# | epoch 2 |  iter 501 / 9295 | time 755[s] | loss 2.16
# | epoch 2 |  iter 521 / 9295 | time 757[s] | loss 2.18
# | epoch 2 |  iter 541 / 9295 | time 759[s] | loss 2.13
# | epoch 2 |  iter 561 / 9295 | time 760[s] | loss 2.16
# | epoch 2 |  iter 581 / 9295 | time 762[s] | loss 2.18
# | epoch 2 |  iter 601 / 9295 | time 764[s] | loss 2.18
# | epoch 2 |  iter 621 / 9295 | time 766[s] | loss 2.15
# | epoch 2 |  iter 641 / 9295 | time 767[s] | loss 2.19
# | epoch 2 |  iter 661 / 9295 | time 769[s] | loss 2.14
# | epoch 2 |  iter 681 / 9295 | time 771[s] | loss 2.17
# | epoch 2 |  iter 701 / 9295 | time 772[s] | loss 2.16
# | epoch 2 |  iter 721 / 9295 | time 774[s] | loss 2.19
# | epoch 2 |  iter 741 / 9295 | time 776[s] | loss 2.17
# | epoch 2 |  iter 761 / 9295 | time 777[s] | loss 2.15
# | epoch 2 |  iter 781 / 9295 | time 779[s] | loss 2.16
# | epoch 2 |  iter 801 / 9295 | time 780[s] | loss 2.16
# | epoch 2 |  iter 821 / 9295 | time 782[s] | loss 2.16
# | epoch 2 |  iter 841 / 9295 | time 784[s] | loss 2.14
# | epoch 2 |  iter 861 / 9295 | time 785[s] | loss 2.16
# | epoch 2 |  iter 881 / 9295 | time 787[s] | loss 2.15
# | epoch 2 |  iter 901 / 9295 | time 788[s] | loss 2.19
# | epoch 2 |  iter 921 / 9295 | time 790[s] | loss 2.18
# | epoch 2 |  iter 941 / 9295 | time 791[s] | loss 2.16
# | epoch 2 |  iter 961 / 9295 | time 793[s] | loss 2.13
# | epoch 2 |  iter 981 / 9295 | time 795[s] | loss 2.16
# | epoch 2 |  iter 1001 / 9295 | time 796[s] | loss 2.14
# | epoch 2 |  iter 1021 / 9295 | time 798[s] | loss 2.20
# | epoch 2 |  iter 1041 / 9295 | time 799[s] | loss 2.16
# | epoch 2 |  iter 1061 / 9295 | time 801[s] | loss 2.18
# | epoch 2 |  iter 1081 / 9295 | time 803[s] | loss 2.16
# | epoch 2 |  iter 1101 / 9295 | time 804[s] | loss 2.19
# | epoch 2 |  iter 1121 / 9295 | time 806[s] | loss 2.18
# | epoch 2 |  iter 1141 / 9295 | time 807[s] | loss 2.12
# | epoch 2 |  iter 1161 / 9295 | time 809[s] | loss 2.14
# | epoch 2 |  iter 1181 / 9295 | time 810[s] | loss 2.19
# | epoch 2 |  iter 1201 / 9295 | time 812[s] | loss 2.14
# | epoch 2 |  iter 1221 / 9295 | time 813[s] | loss 2.19
# | epoch 2 |  iter 1241 / 9295 | time 815[s] | loss 2.14
# | epoch 2 |  iter 1261 / 9295 | time 817[s] | loss 2.13
# | epoch 2 |  iter 1281 / 9295 | time 818[s] | loss 2.17
# | epoch 2 |  iter 1301 / 9295 | time 820[s] | loss 2.16
# | epoch 2 |  iter 1321 / 9295 | time 821[s] | loss 2.14
# | epoch 2 |  iter 1341 / 9295 | time 823[s] | loss 2.15
# | epoch 2 |  iter 1361 / 9295 | time 825[s] | loss 2.18
# | epoch 2 |  iter 1381 / 9295 | time 826[s] | loss 2.14
# | epoch 2 |  iter 1401 / 9295 | time 828[s] | loss 2.14
# | epoch 2 |  iter 1421 / 9295 | time 829[s] | loss 2.16
# | epoch 2 |  iter 1441 / 9295 | time 831[s] | loss 2.17
# | epoch 2 |  iter 1461 / 9295 | time 832[s] | loss 2.18
# | epoch 2 |  iter 1481 / 9295 | time 834[s] | loss 2.15
# | epoch 2 |  iter 1501 / 9295 | time 836[s] | loss 2.16
# | epoch 2 |  iter 1521 / 9295 | time 837[s] | loss 2.13
# | epoch 2 |  iter 1541 / 9295 | time 839[s] | loss 2.13
# | epoch 2 |  iter 1561 / 9295 | time 840[s] | loss 2.14
# | epoch 2 |  iter 1581 / 9295 | time 842[s] | loss 2.16
# | epoch 2 |  iter 1601 / 9295 | time 843[s] | loss 2.14
# | epoch 2 |  iter 1621 / 9295 | time 845[s] | loss 2.11
# | epoch 2 |  iter 1641 / 9295 | time 846[s] | loss 2.16
# | epoch 2 |  iter 1661 / 9295 | time 848[s] | loss 2.15
# | epoch 2 |  iter 1681 / 9295 | time 849[s] | loss 2.17
# | epoch 2 |  iter 1701 / 9295 | time 851[s] | loss 2.14
# | epoch 2 |  iter 1721 / 9295 | time 852[s] | loss 2.15
# | epoch 2 |  iter 1741 / 9295 | time 854[s] | loss 2.12
# | epoch 2 |  iter 1761 / 9295 | time 855[s] | loss 2.15
# | epoch 2 |  iter 1781 / 9295 | time 857[s] | loss 2.18
# | epoch 2 |  iter 1801 / 9295 | time 858[s] | loss 2.16
# | epoch 2 |  iter 1821 / 9295 | time 860[s] | loss 2.12
# | epoch 2 |  iter 1841 / 9295 | time 861[s] | loss 2.16
# | epoch 2 |  iter 1861 / 9295 | time 863[s] | loss 2.14
# | epoch 2 |  iter 1881 / 9295 | time 864[s] | loss 2.13
# | epoch 2 |  iter 1901 / 9295 | time 866[s] | loss 2.12
# | epoch 2 |  iter 1921 / 9295 | time 867[s] | loss 2.12
# | epoch 2 |  iter 1941 / 9295 | time 869[s] | loss 2.11
# | epoch 2 |  iter 1961 / 9295 | time 870[s] | loss 2.14
# | epoch 2 |  iter 1981 / 9295 | time 872[s] | loss 2.13
# | epoch 2 |  iter 2001 / 9295 | time 874[s] | loss 2.11
# | epoch 2 |  iter 2021 / 9295 | time 875[s] | loss 2.16
# | epoch 2 |  iter 2041 / 9295 | time 877[s] | loss 2.12
# | epoch 2 |  iter 2061 / 9295 | time 878[s] | loss 2.16
# | epoch 2 |  iter 2081 / 9295 | time 880[s] | loss 2.16
# | epoch 2 |  iter 2101 / 9295 | time 882[s] | loss 2.10
# | epoch 2 |  iter 2121 / 9295 | time 883[s] | loss 2.11
# | epoch 2 |  iter 2141 / 9295 | time 884[s] | loss 2.17
# | epoch 2 |  iter 2161 / 9295 | time 886[s] | loss 2.14
# | epoch 2 |  iter 2181 / 9295 | time 887[s] | loss 2.14
# | epoch 2 |  iter 2201 / 9295 | time 889[s] | loss 2.10
# | epoch 2 |  iter 2221 / 9295 | time 890[s] | loss 2.12
# | epoch 2 |  iter 2241 / 9295 | time 892[s] | loss 2.13
# | epoch 2 |  iter 2261 / 9295 | time 894[s] | loss 2.14
# | epoch 2 |  iter 2281 / 9295 | time 895[s] | loss 2.16
# | epoch 2 |  iter 2301 / 9295 | time 897[s] | loss 2.10
# | epoch 2 |  iter 2321 / 9295 | time 898[s] | loss 2.09
# | epoch 2 |  iter 2341 / 9295 | time 900[s] | loss 2.14
# | epoch 2 |  iter 2361 / 9295 | time 901[s] | loss 2.16
# | epoch 2 |  iter 2381 / 9295 | time 902[s] | loss 2.13
# | epoch 2 |  iter 2401 / 9295 | time 904[s] | loss 2.11
# | epoch 2 |  iter 2421 / 9295 | time 905[s] | loss 2.11
# | epoch 2 |  iter 2441 / 9295 | time 907[s] | loss 2.11
# | epoch 2 |  iter 2461 / 9295 | time 908[s] | loss 2.09
# | epoch 2 |  iter 2481 / 9295 | time 910[s] | loss 2.11
# | epoch 2 |  iter 2501 / 9295 | time 911[s] | loss 2.11
# | epoch 2 |  iter 2521 / 9295 | time 913[s] | loss 2.13
# | epoch 2 |  iter 2541 / 9295 | time 914[s] | loss 2.11
# | epoch 2 |  iter 2561 / 9295 | time 916[s] | loss 2.12
# | epoch 2 |  iter 2581 / 9295 | time 917[s] | loss 2.16
# | epoch 2 |  iter 2601 / 9295 | time 918[s] | loss 2.14
# | epoch 2 |  iter 2621 / 9295 | time 920[s] | loss 2.11
# | epoch 2 |  iter 2641 / 9295 | time 921[s] | loss 2.14
# | epoch 2 |  iter 2661 / 9295 | time 924[s] | loss 2.13
# | epoch 2 |  iter 2681 / 9295 | time 925[s] | loss 2.12
# | epoch 2 |  iter 2701 / 9295 | time 927[s] | loss 2.11
# | epoch 2 |  iter 2721 / 9295 | time 928[s] | loss 2.12
# | epoch 2 |  iter 2741 / 9295 | time 930[s] | loss 2.15
# | epoch 2 |  iter 2761 / 9295 | time 932[s] | loss 2.09
# | epoch 2 |  iter 2781 / 9295 | time 934[s] | loss 2.14
# | epoch 2 |  iter 2801 / 9295 | time 935[s] | loss 2.10
# | epoch 2 |  iter 2821 / 9295 | time 937[s] | loss 2.09
# | epoch 2 |  iter 2841 / 9295 | time 938[s] | loss 2.12
# | epoch 2 |  iter 2861 / 9295 | time 940[s] | loss 2.16
# | epoch 2 |  iter 2881 / 9295 | time 942[s] | loss 2.11
# | epoch 2 |  iter 2901 / 9295 | time 943[s] | loss 2.15
# | epoch 2 |  iter 2921 / 9295 | time 945[s] | loss 2.13
# | epoch 2 |  iter 2941 / 9295 | time 946[s] | loss 2.09
# | epoch 2 |  iter 2961 / 9295 | time 947[s] | loss 2.09
# | epoch 2 |  iter 2981 / 9295 | time 949[s] | loss 2.12
# | epoch 2 |  iter 3001 / 9295 | time 950[s] | loss 2.12
# | epoch 2 |  iter 3021 / 9295 | time 952[s] | loss 2.13
# | epoch 2 |  iter 3041 / 9295 | time 954[s] | loss 2.12
# | epoch 2 |  iter 3061 / 9295 | time 955[s] | loss 2.06
# | epoch 2 |  iter 3081 / 9295 | time 957[s] | loss 2.13
# | epoch 2 |  iter 3101 / 9295 | time 958[s] | loss 2.09
# | epoch 2 |  iter 3121 / 9295 | time 960[s] | loss 2.10
# | epoch 2 |  iter 3141 / 9295 | time 961[s] | loss 2.10
# | epoch 2 |  iter 3161 / 9295 | time 963[s] | loss 2.12
# | epoch 2 |  iter 3181 / 9295 | time 965[s] | loss 2.07
# | epoch 2 |  iter 3201 / 9295 | time 966[s] | loss 2.13
# | epoch 2 |  iter 3221 / 9295 | time 968[s] | loss 2.18
# | epoch 2 |  iter 3241 / 9295 | time 970[s] | loss 2.12
# | epoch 2 |  iter 3261 / 9295 | time 971[s] | loss 2.08
# | epoch 2 |  iter 3281 / 9295 | time 973[s] | loss 2.09
# | epoch 2 |  iter 3301 / 9295 | time 974[s] | loss 2.11
# | epoch 2 |  iter 3321 / 9295 | time 976[s] | loss 2.08
# | epoch 2 |  iter 3341 / 9295 | time 977[s] | loss 2.12
# | epoch 2 |  iter 3361 / 9295 | time 979[s] | loss 2.12
# | epoch 2 |  iter 3381 / 9295 | time 980[s] | loss 2.15
# | epoch 2 |  iter 3401 / 9295 | time 981[s] | loss 2.09
# | epoch 2 |  iter 3421 / 9295 | time 984[s] | loss 2.11
# | epoch 2 |  iter 3441 / 9295 | time 985[s] | loss 2.12
# | epoch 2 |  iter 3461 / 9295 | time 987[s] | loss 2.09
# | epoch 2 |  iter 3481 / 9295 | time 988[s] | loss 2.08
# | epoch 2 |  iter 3501 / 9295 | time 990[s] | loss 2.13
# | epoch 2 |  iter 3521 / 9295 | time 991[s] | loss 2.10
# | epoch 2 |  iter 3541 / 9295 | time 993[s] | loss 2.09
# | epoch 2 |  iter 3561 / 9295 | time 994[s] | loss 2.13
# | epoch 2 |  iter 3581 / 9295 | time 996[s] | loss 2.09
# | epoch 2 |  iter 3601 / 9295 | time 997[s] | loss 2.11
# | epoch 2 |  iter 3621 / 9295 | time 998[s] | loss 2.12
# | epoch 2 |  iter 3641 / 9295 | time 1000[s] | loss 2.12
# | epoch 2 |  iter 3661 / 9295 | time 1001[s] | loss 2.11
# | epoch 2 |  iter 3681 / 9295 | time 1003[s] | loss 2.09
# | epoch 2 |  iter 3701 / 9295 | time 1004[s] | loss 2.13
# | epoch 2 |  iter 3721 / 9295 | time 1006[s] | loss 2.08
# | epoch 2 |  iter 3741 / 9295 | time 1007[s] | loss 2.12
# | epoch 2 |  iter 3761 / 9295 | time 1009[s] | loss 2.12
# | epoch 2 |  iter 3781 / 9295 | time 1010[s] | loss 2.09
# | epoch 2 |  iter 3801 / 9295 | time 1012[s] | loss 2.11
# | epoch 2 |  iter 3821 / 9295 | time 1014[s] | loss 2.07
# | epoch 2 |  iter 3841 / 9295 | time 1015[s] | loss 2.08
# | epoch 2 |  iter 3861 / 9295 | time 1017[s] | loss 2.12
# | epoch 2 |  iter 3881 / 9295 | time 1019[s] | loss 2.09
# | epoch 2 |  iter 3901 / 9295 | time 1020[s] | loss 2.10
# | epoch 2 |  iter 3921 / 9295 | time 1022[s] | loss 2.10
# | epoch 2 |  iter 3941 / 9295 | time 1023[s] | loss 2.10
# | epoch 2 |  iter 3961 / 9295 | time 1025[s] | loss 2.10
# | epoch 2 |  iter 3981 / 9295 | time 1026[s] | loss 2.10
# | epoch 2 |  iter 4001 / 9295 | time 1028[s] | loss 2.11
# | epoch 2 |  iter 4021 / 9295 | time 1029[s] | loss 2.11
# | epoch 2 |  iter 4041 / 9295 | time 1031[s] | loss 2.08
# | epoch 2 |  iter 4061 / 9295 | time 1032[s] | loss 2.10
# | epoch 2 |  iter 4081 / 9295 | time 1033[s] | loss 2.11
# | epoch 2 |  iter 4101 / 9295 | time 1035[s] | loss 2.08
# | epoch 2 |  iter 4121 / 9295 | time 1036[s] | loss 2.09
# | epoch 2 |  iter 4141 / 9295 | time 1038[s] | loss 2.13
# | epoch 2 |  iter 4161 / 9295 | time 1039[s] | loss 2.09
# | epoch 2 |  iter 4181 / 9295 | time 1041[s] | loss 2.06
# | epoch 2 |  iter 4201 / 9295 | time 1042[s] | loss 2.08
# | epoch 2 |  iter 4221 / 9295 | time 1044[s] | loss 2.10
# | epoch 2 |  iter 4241 / 9295 | time 1045[s] | loss 2.11
# | epoch 2 |  iter 4261 / 9295 | time 1047[s] | loss 2.08
# | epoch 2 |  iter 4281 / 9295 | time 1048[s] | loss 2.11
# | epoch 2 |  iter 4301 / 9295 | time 1050[s] | loss 2.09
# | epoch 2 |  iter 4321 / 9295 | time 1051[s] | loss 2.09
# | epoch 2 |  iter 4341 / 9295 | time 1053[s] | loss 2.10
# | epoch 2 |  iter 4361 / 9295 | time 1054[s] | loss 2.07
# | epoch 2 |  iter 4381 / 9295 | time 1056[s] | loss 2.08
# | epoch 2 |  iter 4401 / 9295 | time 1057[s] | loss 2.11
# | epoch 2 |  iter 4421 / 9295 | time 1059[s] | loss 2.09
# | epoch 2 |  iter 4441 / 9295 | time 1060[s] | loss 2.07
# | epoch 2 |  iter 4461 / 9295 | time 1062[s] | loss 2.09
# | epoch 2 |  iter 4481 / 9295 | time 1063[s] | loss 2.13
# | epoch 2 |  iter 4501 / 9295 | time 1065[s] | loss 2.07
# | epoch 2 |  iter 4521 / 9295 | time 1066[s] | loss 2.06
# | epoch 2 |  iter 4541 / 9295 | time 1068[s] | loss 2.11
# | epoch 2 |  iter 4561 / 9295 | time 1069[s] | loss 2.07
# | epoch 2 |  iter 4581 / 9295 | time 1071[s] | loss 2.09
# | epoch 2 |  iter 4601 / 9295 | time 1073[s] | loss 2.08
# | epoch 2 |  iter 4621 / 9295 | time 1074[s] | loss 2.08
# | epoch 2 |  iter 4641 / 9295 | time 1076[s] | loss 2.12
# | epoch 2 |  iter 4661 / 9295 | time 1077[s] | loss 2.10
# | epoch 2 |  iter 4681 / 9295 | time 1079[s] | loss 2.05
# | epoch 2 |  iter 4701 / 9295 | time 1080[s] | loss 2.08
# | epoch 2 |  iter 4721 / 9295 | time 1082[s] | loss 2.07
# | epoch 2 |  iter 4741 / 9295 | time 1083[s] | loss 2.10
# | epoch 2 |  iter 4761 / 9295 | time 1085[s] | loss 2.14
# | epoch 2 |  iter 4781 / 9295 | time 1086[s] | loss 2.08
# | epoch 2 |  iter 4801 / 9295 | time 1088[s] | loss 2.09
# | epoch 2 |  iter 4821 / 9295 | time 1089[s] | loss 2.08
# | epoch 2 |  iter 4841 / 9295 | time 1091[s] | loss 2.10
# | epoch 2 |  iter 4861 / 9295 | time 1092[s] | loss 2.06
# | epoch 2 |  iter 4881 / 9295 | time 1094[s] | loss 2.11
# | epoch 2 |  iter 4901 / 9295 | time 1095[s] | loss 2.09
# | epoch 2 |  iter 4921 / 9295 | time 1097[s] | loss 2.11
# | epoch 2 |  iter 4941 / 9295 | time 1098[s] | loss 2.07
# | epoch 2 |  iter 4961 / 9295 | time 1100[s] | loss 2.06
# | epoch 2 |  iter 4981 / 9295 | time 1101[s] | loss 2.07
# | epoch 2 |  iter 5001 / 9295 | time 1103[s] | loss 2.11
# | epoch 2 |  iter 5021 / 9295 | time 1104[s] | loss 2.09
# | epoch 2 |  iter 5041 / 9295 | time 1106[s] | loss 2.11
# | epoch 2 |  iter 5061 / 9295 | time 1107[s] | loss 2.10
# | epoch 2 |  iter 5081 / 9295 | time 1109[s] | loss 2.06
# | epoch 2 |  iter 5101 / 9295 | time 1110[s] | loss 2.10
# | epoch 2 |  iter 5121 / 9295 | time 1111[s] | loss 2.06
# | epoch 2 |  iter 5141 / 9295 | time 1113[s] | loss 2.08
# | epoch 2 |  iter 5161 / 9295 | time 1114[s] | loss 2.10
# | epoch 2 |  iter 5181 / 9295 | time 1116[s] | loss 2.10
# | epoch 2 |  iter 5201 / 9295 | time 1117[s] | loss 2.09
# | epoch 2 |  iter 5221 / 9295 | time 1119[s] | loss 2.08
# | epoch 2 |  iter 5241 / 9295 | time 1120[s] | loss 2.08
# | epoch 2 |  iter 5261 / 9295 | time 1122[s] | loss 2.09
# | epoch 2 |  iter 5281 / 9295 | time 1123[s] | loss 2.04
# | epoch 2 |  iter 5301 / 9295 | time 1124[s] | loss 2.07
# | epoch 2 |  iter 5321 / 9295 | time 1126[s] | loss 2.07
# | epoch 2 |  iter 5341 / 9295 | time 1127[s] | loss 2.08
# | epoch 2 |  iter 5361 / 9295 | time 1129[s] | loss 2.07
# | epoch 2 |  iter 5381 / 9295 | time 1130[s] | loss 2.04
# | epoch 2 |  iter 5401 / 9295 | time 1132[s] | loss 2.04
# | epoch 2 |  iter 5421 / 9295 | time 1133[s] | loss 2.06
# | epoch 2 |  iter 5441 / 9295 | time 1134[s] | loss 2.10
# | epoch 2 |  iter 5461 / 9295 | time 1136[s] | loss 2.05
# | epoch 2 |  iter 5481 / 9295 | time 1137[s] | loss 2.06
# | epoch 2 |  iter 5501 / 9295 | time 1139[s] | loss 2.08
# | epoch 2 |  iter 5521 / 9295 | time 1140[s] | loss 2.07
# | epoch 2 |  iter 5541 / 9295 | time 1142[s] | loss 2.07
# | epoch 2 |  iter 5561 / 9295 | time 1143[s] | loss 2.11
# | epoch 2 |  iter 5581 / 9295 | time 1145[s] | loss 2.11
# | epoch 2 |  iter 5601 / 9295 | time 1146[s] | loss 2.09
# | epoch 2 |  iter 5621 / 9295 | time 1148[s] | loss 2.05
# | epoch 2 |  iter 5641 / 9295 | time 1149[s] | loss 2.07
# | epoch 2 |  iter 5661 / 9295 | time 1151[s] | loss 2.08
# | epoch 2 |  iter 5681 / 9295 | time 1152[s] | loss 2.02
# | epoch 2 |  iter 5701 / 9295 | time 1154[s] | loss 2.05
# | epoch 2 |  iter 5721 / 9295 | time 1155[s] | loss 2.07
# | epoch 2 |  iter 5741 / 9295 | time 1156[s] | loss 2.06
# | epoch 2 |  iter 5761 / 9295 | time 1158[s] | loss 2.07
# | epoch 2 |  iter 5781 / 9295 | time 1159[s] | loss 2.05
# | epoch 2 |  iter 5801 / 9295 | time 1161[s] | loss 2.05
# | epoch 2 |  iter 5821 / 9295 | time 1162[s] | loss 2.11
# | epoch 2 |  iter 5841 / 9295 | time 1164[s] | loss 2.07
# | epoch 2 |  iter 5861 / 9295 | time 1165[s] | loss 2.05
# | epoch 2 |  iter 5881 / 9295 | time 1167[s] | loss 2.09
# | epoch 2 |  iter 5901 / 9295 | time 1168[s] | loss 2.05
# | epoch 2 |  iter 5921 / 9295 | time 1170[s] | loss 2.10
# | epoch 2 |  iter 5941 / 9295 | time 1171[s] | loss 2.06
# | epoch 2 |  iter 5961 / 9295 | time 1173[s] | loss 2.07
# | epoch 2 |  iter 5981 / 9295 | time 1174[s] | loss 2.06
# | epoch 2 |  iter 6001 / 9295 | time 1176[s] | loss 2.05
# | epoch 2 |  iter 6021 / 9295 | time 1178[s] | loss 2.03
# | epoch 2 |  iter 6041 / 9295 | time 1179[s] | loss 2.07
# | epoch 2 |  iter 6061 / 9295 | time 1180[s] | loss 2.03
# | epoch 2 |  iter 6081 / 9295 | time 1182[s] | loss 2.04
# | epoch 2 |  iter 6101 / 9295 | time 1183[s] | loss 2.08
# | epoch 2 |  iter 6121 / 9295 | time 1185[s] | loss 2.07
# | epoch 2 |  iter 6141 / 9295 | time 1186[s] | loss 2.10
# | epoch 2 |  iter 6161 / 9295 | time 1188[s] | loss 2.08
# | epoch 2 |  iter 6181 / 9295 | time 1189[s] | loss 2.06
# | epoch 2 |  iter 6201 / 9295 | time 1191[s] | loss 2.09
# | epoch 2 |  iter 6221 / 9295 | time 1192[s] | loss 2.05
# | epoch 2 |  iter 6241 / 9295 | time 1194[s] | loss 2.05
# | epoch 2 |  iter 6261 / 9295 | time 1195[s] | loss 2.08
# | epoch 2 |  iter 6281 / 9295 | time 1196[s] | loss 2.03
# | epoch 2 |  iter 6301 / 9295 | time 1198[s] | loss 2.06
# | epoch 2 |  iter 6321 / 9295 | time 1199[s] | loss 2.07
# | epoch 2 |  iter 6341 / 9295 | time 1201[s] | loss 2.03
# | epoch 2 |  iter 6361 / 9295 | time 1202[s] | loss 2.06
# | epoch 2 |  iter 6381 / 9295 | time 1204[s] | loss 2.07
# | epoch 2 |  iter 6401 / 9295 | time 1205[s] | loss 2.07
# | epoch 2 |  iter 6421 / 9295 | time 1207[s] | loss 2.05
# | epoch 2 |  iter 6441 / 9295 | time 1208[s] | loss 2.06
# | epoch 2 |  iter 6461 / 9295 | time 1209[s] | loss 2.03
# | epoch 2 |  iter 6481 / 9295 | time 1211[s] | loss 2.10
# | epoch 2 |  iter 6501 / 9295 | time 1212[s] | loss 2.05
# | epoch 2 |  iter 6521 / 9295 | time 1214[s] | loss 2.03
# | epoch 2 |  iter 6541 / 9295 | time 1215[s] | loss 2.04
# | epoch 2 |  iter 6561 / 9295 | time 1217[s] | loss 2.05
# | epoch 2 |  iter 6581 / 9295 | time 1218[s] | loss 2.08
# | epoch 2 |  iter 6601 / 9295 | time 1220[s] | loss 2.06
# | epoch 2 |  iter 6621 / 9295 | time 1221[s] | loss 2.07
# | epoch 2 |  iter 6641 / 9295 | time 1223[s] | loss 2.06
# | epoch 2 |  iter 6661 / 9295 | time 1224[s] | loss 2.07
# | epoch 2 |  iter 6681 / 9295 | time 1226[s] | loss 2.03
# | epoch 2 |  iter 6701 / 9295 | time 1227[s] | loss 2.04
# | epoch 2 |  iter 6721 / 9295 | time 1229[s] | loss 2.05
# | epoch 2 |  iter 6741 / 9295 | time 1230[s] | loss 2.04
# | epoch 2 |  iter 6761 / 9295 | time 1231[s] | loss 2.01
# | epoch 2 |  iter 6781 / 9295 | time 1233[s] | loss 2.06
# | epoch 2 |  iter 6801 / 9295 | time 1234[s] | loss 2.03
# | epoch 2 |  iter 6821 / 9295 | time 1236[s] | loss 2.02
# | epoch 2 |  iter 6841 / 9295 | time 1237[s] | loss 2.06
# | epoch 2 |  iter 6861 / 9295 | time 1239[s] | loss 2.03
# | epoch 2 |  iter 6881 / 9295 | time 1240[s] | loss 2.06
# | epoch 2 |  iter 6901 / 9295 | time 1242[s] | loss 2.03
# | epoch 2 |  iter 6921 / 9295 | time 1243[s] | loss 2.06
# | epoch 2 |  iter 6941 / 9295 | time 1245[s] | loss 2.04
# | epoch 2 |  iter 6961 / 9295 | time 1246[s] | loss 2.09
# | epoch 2 |  iter 6981 / 9295 | time 1247[s] | loss 2.07
# | epoch 2 |  iter 7001 / 9295 | time 1249[s] | loss 2.04
# | epoch 2 |  iter 7021 / 9295 | time 1250[s] | loss 2.04
# | epoch 2 |  iter 7041 / 9295 | time 1252[s] | loss 2.01
# | epoch 2 |  iter 7061 / 9295 | time 1253[s] | loss 2.06
# | epoch 2 |  iter 7081 / 9295 | time 1255[s] | loss 2.09
# | epoch 2 |  iter 7101 / 9295 | time 1256[s] | loss 2.07
# | epoch 2 |  iter 7121 / 9295 | time 1257[s] | loss 2.03
# | epoch 2 |  iter 7141 / 9295 | time 1259[s] | loss 2.06
# | epoch 2 |  iter 7161 / 9295 | time 1260[s] | loss 2.06
# | epoch 2 |  iter 7181 / 9295 | time 1262[s] | loss 2.07
# | epoch 2 |  iter 7201 / 9295 | time 1263[s] | loss 2.03
# | epoch 2 |  iter 7221 / 9295 | time 1265[s] | loss 2.03
# | epoch 2 |  iter 7241 / 9295 | time 1267[s] | loss 2.03
# | epoch 2 |  iter 7261 / 9295 | time 1268[s] | loss 2.03
# | epoch 2 |  iter 7281 / 9295 | time 1270[s] | loss 2.03
# | epoch 2 |  iter 7301 / 9295 | time 1271[s] | loss 2.02
# | epoch 2 |  iter 7321 / 9295 | time 1273[s] | loss 2.05
# | epoch 2 |  iter 7341 / 9295 | time 1274[s] | loss 2.07
# | epoch 2 |  iter 7361 / 9295 | time 1276[s] | loss 2.02
# | epoch 2 |  iter 7381 / 9295 | time 1277[s] | loss 2.02
# | epoch 2 |  iter 7401 / 9295 | time 1279[s] | loss 2.02
# | epoch 2 |  iter 7421 / 9295 | time 1281[s] | loss 2.04
# | epoch 2 |  iter 7441 / 9295 | time 1282[s] | loss 2.01
# | epoch 2 |  iter 7461 / 9295 | time 1284[s] | loss 2.04
# | epoch 2 |  iter 7481 / 9295 | time 1285[s] | loss 2.06
# | epoch 2 |  iter 7501 / 9295 | time 1287[s] | loss 2.04
# | epoch 2 |  iter 7521 / 9295 | time 1288[s] | loss 2.01
# | epoch 2 |  iter 7541 / 9295 | time 1290[s] | loss 2.08
# | epoch 2 |  iter 7561 / 9295 | time 1292[s] | loss 2.05
# | epoch 2 |  iter 7581 / 9295 | time 1293[s] | loss 2.05
# | epoch 2 |  iter 7601 / 9295 | time 1294[s] | loss 2.03
# | epoch 2 |  iter 7621 / 9295 | time 1296[s] | loss 2.07
# | epoch 2 |  iter 7641 / 9295 | time 1297[s] | loss 2.04
# | epoch 2 |  iter 7661 / 9295 | time 1299[s] | loss 2.04
# | epoch 2 |  iter 7681 / 9295 | time 1300[s] | loss 2.04
# | epoch 2 |  iter 7701 / 9295 | time 1302[s] | loss 2.05
# | epoch 2 |  iter 7721 / 9295 | time 1303[s] | loss 2.04
# | epoch 2 |  iter 7741 / 9295 | time 1304[s] | loss 2.02
# | epoch 2 |  iter 7761 / 9295 | time 1306[s] | loss 2.02
# | epoch 2 |  iter 7781 / 9295 | time 1307[s] | loss 2.01
# | epoch 2 |  iter 7801 / 9295 | time 1309[s] | loss 1.99
# ...
# | epoch 10 |  iter 3801 / 9295 | time 6508[s] | loss 1.42
# | epoch 10 |  iter 3821 / 9295 | time 6509[s] | loss 1.42
# | epoch 10 |  iter 3841 / 9295 | time 6511[s] | loss 1.44
# | epoch 10 |  iter 3861 / 9295 | time 6512[s] | loss 1.41
# | epoch 10 |  iter 3881 / 9295 | time 6514[s] | loss 1.45
# | epoch 10 |  iter 3901 / 9295 | time 6515[s] | loss 1.43
# | epoch 10 |  iter 3921 / 9295 | time 6517[s] | loss 1.46
# | epoch 10 |  iter 3941 / 9295 | time 6518[s] | loss 1.47
# | epoch 10 |  iter 3961 / 9295 | time 6519[s] | loss 1.45
# | epoch 10 |  iter 3981 / 9295 | time 6521[s] | loss 1.44
# | epoch 10 |  iter 4001 / 9295 | time 6522[s] | loss 1.48
# | epoch 10 |  iter 4021 / 9295 | time 6524[s] | loss 1.43
# | epoch 10 |  iter 4041 / 9295 | time 6525[s] | loss 1.44
# | epoch 10 |  iter 4061 / 9295 | time 6526[s] | loss 1.44
# | epoch 10 |  iter 4081 / 9295 | time 6528[s] | loss 1.44
# | epoch 10 |  iter 4101 / 9295 | time 6529[s] | loss 1.41
# | epoch 10 |  iter 4121 / 9295 | time 6531[s] | loss 1.46
# | epoch 10 |  iter 4141 / 9295 | time 6532[s] | loss 1.43
# | epoch 10 |  iter 4161 / 9295 | time 6533[s] | loss 1.49
# | epoch 10 |  iter 4181 / 9295 | time 6535[s] | loss 1.46
# | epoch 10 |  iter 4201 / 9295 | time 6536[s] | loss 1.42
# | epoch 10 |  iter 4221 / 9295 | time 6538[s] | loss 1.46
# | epoch 10 |  iter 4241 / 9295 | time 6539[s] | loss 1.42
# | epoch 10 |  iter 4261 / 9295 | time 6541[s] | loss 1.43
# | epoch 10 |  iter 4281 / 9295 | time 6542[s] | loss 1.45
# | epoch 10 |  iter 4301 / 9295 | time 6543[s] | loss 1.46
# | epoch 10 |  iter 4321 / 9295 | time 6545[s] | loss 1.44
# | epoch 10 |  iter 4341 / 9295 | time 6546[s] | loss 1.48
# | epoch 10 |  iter 4361 / 9295 | time 6548[s] | loss 1.40
# | epoch 10 |  iter 4381 / 9295 | time 6549[s] | loss 1.45
# | epoch 10 |  iter 4401 / 9295 | time 6550[s] | loss 1.46
# | epoch 10 |  iter 4421 / 9295 | time 6552[s] | loss 1.43
# | epoch 10 |  iter 4441 / 9295 | time 6553[s] | loss 1.45
# | epoch 10 |  iter 4461 / 9295 | time 6555[s] | loss 1.44
# | epoch 10 |  iter 4481 / 9295 | time 6556[s] | loss 1.43
# | epoch 10 |  iter 4501 / 9295 | time 6557[s] | loss 1.45
# | epoch 10 |  iter 4521 / 9295 | time 6559[s] | loss 1.43
# | epoch 10 |  iter 4541 / 9295 | time 6560[s] | loss 1.45
# | epoch 10 |  iter 4561 / 9295 | time 6562[s] | loss 1.43
# | epoch 10 |  iter 4581 / 9295 | time 6563[s] | loss 1.41
# | epoch 10 |  iter 4601 / 9295 | time 6565[s] | loss 1.46
# | epoch 10 |  iter 4621 / 9295 | time 6566[s] | loss 1.45
# | epoch 10 |  iter 4641 / 9295 | time 6567[s] | loss 1.45
# | epoch 10 |  iter 4661 / 9295 | time 6569[s] | loss 1.43
# | epoch 10 |  iter 4681 / 9295 | time 6570[s] | loss 1.38
# | epoch 10 |  iter 4701 / 9295 | time 6572[s] | loss 1.45
# | epoch 10 |  iter 4721 / 9295 | time 6573[s] | loss 1.43
# | epoch 10 |  iter 4741 / 9295 | time 6574[s] | loss 1.44
# | epoch 10 |  iter 4761 / 9295 | time 6576[s] | loss 1.46
# | epoch 10 |  iter 4781 / 9295 | time 6577[s] | loss 1.47
# | epoch 10 |  iter 4801 / 9295 | time 6579[s] | loss 1.44
# | epoch 10 |  iter 4821 / 9295 | time 6580[s] | loss 1.40
# | epoch 10 |  iter 4841 / 9295 | time 6582[s] | loss 1.47
# | epoch 10 |  iter 4861 / 9295 | time 6583[s] | loss 1.44
# | epoch 10 |  iter 4881 / 9295 | time 6585[s] | loss 1.44
# | epoch 10 |  iter 4901 / 9295 | time 6586[s] | loss 1.43
# | epoch 10 |  iter 4921 / 9295 | time 6588[s] | loss 1.46
# | epoch 10 |  iter 4941 / 9295 | time 6589[s] | loss 1.42
# | epoch 10 |  iter 4961 / 9295 | time 6590[s] | loss 1.45
# | epoch 10 |  iter 4981 / 9295 | time 6592[s] | loss 1.44
# | epoch 10 |  iter 5001 / 9295 | time 6593[s] | loss 1.41
# | epoch 10 |  iter 5021 / 9295 | time 6595[s] | loss 1.42
# | epoch 10 |  iter 5041 / 9295 | time 6596[s] | loss 1.48
# | epoch 10 |  iter 5061 / 9295 | time 6598[s] | loss 1.44
# | epoch 10 |  iter 5081 / 9295 | time 6599[s] | loss 1.42
# | epoch 10 |  iter 5101 / 9295 | time 6600[s] | loss 1.44
# | epoch 10 |  iter 5121 / 9295 | time 6602[s] | loss 1.45
# | epoch 10 |  iter 5141 / 9295 | time 6603[s] | loss 1.47
# | epoch 10 |  iter 5161 / 9295 | time 6605[s] | loss 1.45
# | epoch 10 |  iter 5181 / 9295 | time 6606[s] | loss 1.47
# | epoch 10 |  iter 5201 / 9295 | time 6607[s] | loss 1.43
# | epoch 10 |  iter 5221 / 9295 | time 6609[s] | loss 1.43
# | epoch 10 |  iter 5241 / 9295 | time 6610[s] | loss 1.42
# | epoch 10 |  iter 5261 / 9295 | time 6612[s] | loss 1.47
# | epoch 10 |  iter 5281 / 9295 | time 6613[s] | loss 1.46
# | epoch 10 |  iter 5301 / 9295 | time 6615[s] | loss 1.43
# | epoch 10 |  iter 5321 / 9295 | time 6616[s] | loss 1.44
# | epoch 10 |  iter 5341 / 9295 | time 6617[s] | loss 1.44
# | epoch 10 |  iter 5361 / 9295 | time 6619[s] | loss 1.45
# | epoch 10 |  iter 5381 / 9295 | time 6620[s] | loss 1.42
# | epoch 10 |  iter 5401 / 9295 | time 6622[s] | loss 1.44
# | epoch 10 |  iter 5421 / 9295 | time 6623[s] | loss 1.45
# | epoch 10 |  iter 5441 / 9295 | time 6624[s] | loss 1.44
# | epoch 10 |  iter 5461 / 9295 | time 6626[s] | loss 1.42
# | epoch 10 |  iter 5481 / 9295 | time 6627[s] | loss 1.45
# | epoch 10 |  iter 5501 / 9295 | time 6629[s] | loss 1.44
# | epoch 10 |  iter 5521 / 9295 | time 6630[s] | loss 1.41
# | epoch 10 |  iter 5541 / 9295 | time 6632[s] | loss 1.46
# | epoch 10 |  iter 5561 / 9295 | time 6633[s] | loss 1.46
# | epoch 10 |  iter 5581 / 9295 | time 6634[s] | loss 1.46
# | epoch 10 |  iter 5601 / 9295 | time 6636[s] | loss 1.48
# | epoch 10 |  iter 5621 / 9295 | time 6637[s] | loss 1.46
# | epoch 10 |  iter 5641 / 9295 | time 6639[s] | loss 1.42
# | epoch 10 |  iter 5661 / 9295 | time 6640[s] | loss 1.45
# | epoch 10 |  iter 5681 / 9295 | time 6641[s] | loss 1.43
# | epoch 10 |  iter 5701 / 9295 | time 6643[s] | loss 1.44
# | epoch 10 |  iter 5721 / 9295 | time 6644[s] | loss 1.47
# | epoch 10 |  iter 5741 / 9295 | time 6646[s] | loss 1.45
# | epoch 10 |  iter 5761 / 9295 | time 6647[s] | loss 1.43
# | epoch 10 |  iter 5781 / 9295 | time 6648[s] | loss 1.46
# | epoch 10 |  iter 5801 / 9295 | time 6650[s] | loss 1.44
# | epoch 10 |  iter 5821 / 9295 | time 6651[s] | loss 1.44
# | epoch 10 |  iter 5841 / 9295 | time 6653[s] | loss 1.46
# | epoch 10 |  iter 5861 / 9295 | time 6654[s] | loss 1.46
# | epoch 10 |  iter 5881 / 9295 | time 6656[s] | loss 1.45
# | epoch 10 |  iter 5901 / 9295 | time 6657[s] | loss 1.51
# | epoch 10 |  iter 5921 / 9295 | time 6658[s] | loss 1.46
# | epoch 10 |  iter 5941 / 9295 | time 6660[s] | loss 1.44
# | epoch 10 |  iter 5961 / 9295 | time 6661[s] | loss 1.47
# | epoch 10 |  iter 5981 / 9295 | time 6663[s] | loss 1.46
# | epoch 10 |  iter 6001 / 9295 | time 6664[s] | loss 1.44
# | epoch 10 |  iter 6021 / 9295 | time 6665[s] | loss 1.44
# | epoch 10 |  iter 6041 / 9295 | time 6667[s] | loss 1.48
# | epoch 10 |  iter 6061 / 9295 | time 6668[s] | loss 1.42
# | epoch 10 |  iter 6081 / 9295 | time 6670[s] | loss 1.45
# | epoch 10 |  iter 6101 / 9295 | time 6671[s] | loss 1.43
# | epoch 10 |  iter 6121 / 9295 | time 6672[s] | loss 1.41
# | epoch 10 |  iter 6141 / 9295 | time 6674[s] | loss 1.45
# | epoch 10 |  iter 6161 / 9295 | time 6675[s] | loss 1.42
# | epoch 10 |  iter 6181 / 9295 | time 6677[s] | loss 1.46
# | epoch 10 |  iter 6201 / 9295 | time 6678[s] | loss 1.44
# | epoch 10 |  iter 6221 / 9295 | time 6680[s] | loss 1.46
# | epoch 10 |  iter 6241 / 9295 | time 6681[s] | loss 1.47
# | epoch 10 |  iter 6261 / 9295 | time 6682[s] | loss 1.45
# | epoch 10 |  iter 6281 / 9295 | time 6684[s] | loss 1.46
# | epoch 10 |  iter 6301 / 9295 | time 6685[s] | loss 1.45
# | epoch 10 |  iter 6321 / 9295 | time 6687[s] | loss 1.43
# | epoch 10 |  iter 6341 / 9295 | time 6688[s] | loss 1.48
# | epoch 10 |  iter 6361 / 9295 | time 6689[s] | loss 1.45
# | epoch 10 |  iter 6381 / 9295 | time 6691[s] | loss 1.44
# | epoch 10 |  iter 6401 / 9295 | time 6692[s] | loss 1.47
# | epoch 10 |  iter 6421 / 9295 | time 6694[s] | loss 1.46
# | epoch 10 |  iter 6441 / 9295 | time 6695[s] | loss 1.48
# | epoch 10 |  iter 6461 / 9295 | time 6696[s] | loss 1.43
# | epoch 10 |  iter 6481 / 9295 | time 6698[s] | loss 1.44
# | epoch 10 |  iter 6501 / 9295 | time 6699[s] | loss 1.49
# | epoch 10 |  iter 6521 / 9295 | time 6701[s] | loss 1.42
# | epoch 10 |  iter 6541 / 9295 | time 6702[s] | loss 1.41
# | epoch 10 |  iter 6561 / 9295 | time 6703[s] | loss 1.45
# | epoch 10 |  iter 6581 / 9295 | time 6705[s] | loss 1.48
# | epoch 10 |  iter 6601 / 9295 | time 6706[s] | loss 1.44
# | epoch 10 |  iter 6621 / 9295 | time 6708[s] | loss 1.49
# | epoch 10 |  iter 6641 / 9295 | time 6709[s] | loss 1.46
# | epoch 10 |  iter 6661 / 9295 | time 6710[s] | loss 1.42
# | epoch 10 |  iter 6681 / 9295 | time 6712[s] | loss 1.44
# | epoch 10 |  iter 6701 / 9295 | time 6713[s] | loss 1.47
# | epoch 10 |  iter 6721 / 9295 | time 6715[s] | loss 1.48
# | epoch 10 |  iter 6741 / 9295 | time 6716[s] | loss 1.48
# | epoch 10 |  iter 6761 / 9295 | time 6717[s] | loss 1.47
# | epoch 10 |  iter 6781 / 9295 | time 6719[s] | loss 1.44
# | epoch 10 |  iter 6801 / 9295 | time 6720[s] | loss 1.46
# | epoch 10 |  iter 6821 / 9295 | time 6722[s] | loss 1.45
# | epoch 10 |  iter 6841 / 9295 | time 6723[s] | loss 1.46
# | epoch 10 |  iter 6861 / 9295 | time 6725[s] | loss 1.46
# | epoch 10 |  iter 6881 / 9295 | time 6726[s] | loss 1.47
# | epoch 10 |  iter 6901 / 9295 | time 6727[s] | loss 1.46
# | epoch 10 |  iter 6921 / 9295 | time 6729[s] | loss 1.48
# | epoch 10 |  iter 6941 / 9295 | time 6730[s] | loss 1.44
# | epoch 10 |  iter 6961 / 9295 | time 6732[s] | loss 1.44
# | epoch 10 |  iter 6981 / 9295 | time 6733[s] | loss 1.45
# | epoch 10 |  iter 7001 / 9295 | time 6734[s] | loss 1.42
# | epoch 10 |  iter 7021 / 9295 | time 6736[s] | loss 1.45
# | epoch 10 |  iter 7041 / 9295 | time 6737[s] | loss 1.44
# | epoch 10 |  iter 7061 / 9295 | time 6739[s] | loss 1.47
# | epoch 10 |  iter 7081 / 9295 | time 6740[s] | loss 1.47
# | epoch 10 |  iter 7101 / 9295 | time 6741[s] | loss 1.45
# | epoch 10 |  iter 7121 / 9295 | time 6743[s] | loss 1.46
# | epoch 10 |  iter 7141 / 9295 | time 6744[s] | loss 1.46
# | epoch 10 |  iter 7161 / 9295 | time 6746[s] | loss 1.48
# | epoch 10 |  iter 7181 / 9295 | time 6747[s] | loss 1.41
# | epoch 10 |  iter 7201 / 9295 | time 6748[s] | loss 1.45
# | epoch 10 |  iter 7221 / 9295 | time 6750[s] | loss 1.48
# | epoch 10 |  iter 7241 / 9295 | time 6751[s] | loss 1.45
# | epoch 10 |  iter 7261 / 9295 | time 6753[s] | loss 1.49
# | epoch 10 |  iter 7281 / 9295 | time 6754[s] | loss 1.45
# | epoch 10 |  iter 7301 / 9295 | time 6755[s] | loss 1.46
# | epoch 10 |  iter 7321 / 9295 | time 6757[s] | loss 1.44
# | epoch 10 |  iter 7341 / 9295 | time 6758[s] | loss 1.49
# | epoch 10 |  iter 7361 / 9295 | time 6760[s] | loss 1.46
# | epoch 10 |  iter 7381 / 9295 | time 6761[s] | loss 1.43
# | epoch 10 |  iter 7401 / 9295 | time 6763[s] | loss 1.45
# | epoch 10 |  iter 7421 / 9295 | time 6764[s] | loss 1.44
# | epoch 10 |  iter 7441 / 9295 | time 6765[s] | loss 1.48
# | epoch 10 |  iter 7461 / 9295 | time 6767[s] | loss 1.40
# | epoch 10 |  iter 7481 / 9295 | time 6768[s] | loss 1.43
# | epoch 10 |  iter 7501 / 9295 | time 6770[s] | loss 1.45
# | epoch 10 |  iter 7521 / 9295 | time 6771[s] | loss 1.49
# | epoch 10 |  iter 7541 / 9295 | time 6772[s] | loss 1.46
# | epoch 10 |  iter 7561 / 9295 | time 6774[s] | loss 1.44
# | epoch 10 |  iter 7581 / 9295 | time 6775[s] | loss 1.44
# | epoch 10 |  iter 7601 / 9295 | time 6777[s] | loss 1.44
# | epoch 10 |  iter 7621 / 9295 | time 6778[s] | loss 1.47
# | epoch 10 |  iter 7641 / 9295 | time 6780[s] | loss 1.46
# | epoch 10 |  iter 7661 / 9295 | time 6781[s] | loss 1.43
# | epoch 10 |  iter 7681 / 9295 | time 6782[s] | loss 1.49
# | epoch 10 |  iter 7701 / 9295 | time 6784[s] | loss 1.47
# | epoch 10 |  iter 7721 / 9295 | time 6785[s] | loss 1.42
# | epoch 10 |  iter 7741 / 9295 | time 6786[s] | loss 1.48
# | epoch 10 |  iter 7761 / 9295 | time 6788[s] | loss 1.49
# | epoch 10 |  iter 7781 / 9295 | time 6789[s] | loss 1.43
# | epoch 10 |  iter 7801 / 9295 | time 6791[s] | loss 1.40
# | epoch 10 |  iter 7821 / 9295 | time 6792[s] | loss 1.44
# | epoch 10 |  iter 7841 / 9295 | time 6794[s] | loss 1.47
# | epoch 10 |  iter 7861 / 9295 | time 6795[s] | loss 1.41
# | epoch 10 |  iter 7881 / 9295 | time 6796[s] | loss 1.47
# | epoch 10 |  iter 7901 / 9295 | time 6798[s] | loss 1.45
# | epoch 10 |  iter 7921 / 9295 | time 6799[s] | loss 1.43
# | epoch 10 |  iter 7941 / 9295 | time 6801[s] | loss 1.45
# | epoch 10 |  iter 7961 / 9295 | time 6802[s] | loss 1.42
# | epoch 10 |  iter 7981 / 9295 | time 6803[s] | loss 1.43
# | epoch 10 |  iter 8001 / 9295 | time 6805[s] | loss 1.43
# | epoch 10 |  iter 8021 / 9295 | time 6806[s] | loss 1.48
# | epoch 10 |  iter 8041 / 9295 | time 6808[s] | loss 1.47
# | epoch 10 |  iter 8061 / 9295 | time 6809[s] | loss 1.47
# | epoch 10 |  iter 8081 / 9295 | time 6811[s] | loss 1.46
# | epoch 10 |  iter 8101 / 9295 | time 6812[s] | loss 1.47
# | epoch 10 |  iter 8121 / 9295 | time 6813[s] | loss 1.47
# | epoch 10 |  iter 8141 / 9295 | time 6815[s] | loss 1.44
# | epoch 10 |  iter 8161 / 9295 | time 6816[s] | loss 1.44
# | epoch 10 |  iter 8181 / 9295 | time 6818[s] | loss 1.46
# | epoch 10 |  iter 8201 / 9295 | time 6819[s] | loss 1.46
# | epoch 10 |  iter 8221 / 9295 | time 6820[s] | loss 1.43
# | epoch 10 |  iter 8241 / 9295 | time 6822[s] | loss 1.40
# | epoch 10 |  iter 8261 / 9295 | time 6823[s] | loss 1.46
# | epoch 10 |  iter 8281 / 9295 | time 6825[s] | loss 1.46
# | epoch 10 |  iter 8301 / 9295 | time 6826[s] | loss 1.47
# | epoch 10 |  iter 8321 / 9295 | time 6827[s] | loss 1.44
# | epoch 10 |  iter 8341 / 9295 | time 6829[s] | loss 1.46
# | epoch 10 |  iter 8361 / 9295 | time 6830[s] | loss 1.46
# | epoch 10 |  iter 8381 / 9295 | time 6832[s] | loss 1.44
# | epoch 10 |  iter 8401 / 9295 | time 6833[s] | loss 1.47
# | epoch 10 |  iter 8421 / 9295 | time 6834[s] | loss 1.50
# | epoch 10 |  iter 8441 / 9295 | time 6836[s] | loss 1.45
# | epoch 10 |  iter 8461 / 9295 | time 6837[s] | loss 1.47
# | epoch 10 |  iter 8481 / 9295 | time 6839[s] | loss 1.47
# | epoch 10 |  iter 8501 / 9295 | time 6840[s] | loss 1.50
# | epoch 10 |  iter 8521 / 9295 | time 6842[s] | loss 1.45
# | epoch 10 |  iter 8541 / 9295 | time 6843[s] | loss 1.47
# | epoch 10 |  iter 8561 / 9295 | time 6844[s] | loss 1.46
# | epoch 10 |  iter 8581 / 9295 | time 6846[s] | loss 1.46
# | epoch 10 |  iter 8601 / 9295 | time 6847[s] | loss 1.44
# | epoch 10 |  iter 8621 / 9295 | time 6849[s] | loss 1.42
# | epoch 10 |  iter 8641 / 9295 | time 6850[s] | loss 1.43
# | epoch 10 |  iter 8661 / 9295 | time 6851[s] | loss 1.48
# | epoch 10 |  iter 8681 / 9295 | time 6853[s] | loss 1.43
# | epoch 10 |  iter 8701 / 9295 | time 6854[s] | loss 1.45
# | epoch 10 |  iter 8721 / 9295 | time 6856[s] | loss 1.46
# | epoch 10 |  iter 8741 / 9295 | time 6857[s] | loss 1.46
# | epoch 10 |  iter 8761 / 9295 | time 6859[s] | loss 1.49
# | epoch 10 |  iter 8781 / 9295 | time 6860[s] | loss 1.44
# | epoch 10 |  iter 8801 / 9295 | time 6861[s] | loss 1.43
# | epoch 10 |  iter 8821 / 9295 | time 6863[s] | loss 1.46
# | epoch 10 |  iter 8841 / 9295 | time 6864[s] | loss 1.49
# | epoch 10 |  iter 8861 / 9295 | time 6866[s] | loss 1.46
# | epoch 10 |  iter 8881 / 9295 | time 6867[s] | loss 1.51
# | epoch 10 |  iter 8901 / 9295 | time 6868[s] | loss 1.43
# | epoch 10 |  iter 8921 / 9295 | time 6870[s] | loss 1.44
# | epoch 10 |  iter 8941 / 9295 | time 6871[s] | loss 1.44
# | epoch 10 |  iter 8961 / 9295 | time 6873[s] | loss 1.46
# | epoch 10 |  iter 8981 / 9295 | time 6874[s] | loss 1.45
# | epoch 10 |  iter 9001 / 9295 | time 6875[s] | loss 1.44
# | epoch 10 |  iter 9021 / 9295 | time 6877[s] | loss 1.44
# | epoch 10 |  iter 9041 / 9295 | time 6879[s] | loss 1.45
# | epoch 10 |  iter 9061 / 9295 | time 6880[s] | loss 1.49
# | epoch 10 |  iter 9081 / 9295 | time 6882[s] | loss 1.45
# | epoch 10 |  iter 9101 / 9295 | time 6883[s] | loss 1.47
# | epoch 10 |  iter 9121 / 9295 | time 6884[s] | loss 1.46
# | epoch 10 |  iter 9141 / 9295 | time 6886[s] | loss 1.43
# | epoch 10 |  iter 9161 / 9295 | time 6887[s] | loss 1.47
# | epoch 10 |  iter 9181 / 9295 | time 6889[s] | loss 1.39
# | epoch 10 |  iter 9201 / 9295 | time 6890[s] | loss 1.47
# | epoch 10 |  iter 9221 / 9295 | time 6891[s] | loss 1.43
# | epoch 10 |  iter 9241 / 9295 | time 6893[s] | loss 1.49
# | epoch 10 |  iter 9261 / 9295 | time 6894[s] | loss 1.45
# | epoch 10 |  iter 9281 / 9295 | time 6896[s] | loss 1.44

# %%
from common.util import most_similar, analogy
import pickle

pkl_file = 'cbow_params.pkl'
# pkl_file = 'skipgram_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']

# most similar task
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# analogy task
print('-'*50)
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# [query] you
#  we: 0.76171875
#  i: 0.68115234375
#  your: 0.62158203125
#  they: 0.60205078125
#  anything: 0.59814453125
#
# [query] year
#  month: 0.8642578125
#  week: 0.77294921875
#  summer: 0.748046875
#  spring: 0.74462890625
#  decade: 0.677734375
#
# [query] car
#  truck: 0.64794921875
#  window: 0.5771484375
#  luxury: 0.57470703125
#  auto: 0.5732421875
#  cars: 0.54345703125
#
# [query] toyota
#  coated: 0.6533203125
#  honda: 0.65185546875
#  seita: 0.650390625
#  fuel: 0.62939453125
#  weyerhaeuser: 0.62353515625
# --------------------------------------------------
#
# [analogy] king:man = queen:?
#  a.m: 5.66015625
#  naczelnik: 5.0078125
#  woman: 4.9609375
#  carolinas: 4.6484375
#  toxin: 4.625
#
# [analogy] take:took = go:?
#  eurodollars: 4.5390625
#  a.m: 4.4921875
#  're: 4.2421875
#  were: 4.20703125
#  went: 3.953125
#
# [analogy] car:cars = child:?
#  a.m: 7.37890625
#  rape: 6.15625
#  incest: 5.484375
#  daffynition: 5.20703125
#  children: 4.87890625
#
# [analogy] good:better = bad:?
#  more: 5.703125
#  rather: 5.29296875
#  less: 5.23828125
#  greater: 4.65234375
#  worse: 3.837890625
